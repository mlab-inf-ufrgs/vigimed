# %% [markdown]
# ## Setup

# %%
# %pip uninstall -y prettytable
# %pip install prettytable==3.10.0
# %pip install -U jupysql
# Out:
# Found existing installation: prettytable 3.16.0
# Uninstalling prettytable-3.16.0:
#   Successfully uninstalled prettytable-3.16.0
# Note: you may need to restart the kernel to use updated packages.
# Collecting prettytable==3.10.0
#   Using cached prettytable-3.10.0-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: wcwidth in c:\users\janet\documents\vigimed\vigimed\.venv\lib\site-packages (from prettytable==3.10.0) (0.2.13)
# Using cached prettytable-3.10.0-py3-none-any.whl (28 kB)
# Installing collected packages: prettytable
# Successfully installed prettytable-3.10.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupysql 0.11.1 requires prettytable>=3.12.0, but you have prettytable 3.10.0 which is incompatible.
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: jupysql in c:\users\janet\documents\vigimed\vigimed\.venv\lib\site-packages (0.11.1)Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting prettytable>=3.12.0 (from jupysql)
#   Using cached prettytable-3.16.0-py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: sqlalchemy in c:\users\janet\documents\vigimed\vigimed\.venv\lib\site-packages (from jupysql) (2.0.43)
# Requirement already satisfied: sqlparse in c:\users\janet\documents\vigimed\vigimed\.venv\lib\site-packages (from jupysql) (0.5.3)
# Requirement already satisfied: ipython-genutils>=0.1.0 in c:\users\janet\documents\vigimed\vigimed\.venv\lib\site-packages (from jupysql) (0.2.0)
# Requirement already satisfied: jinja2 in c:\users\janet\documents\vigimed\vigimed\.venv\lib\site-packages (from jupysql) (3.1.6)
# Requirement already satisfied: sqlglot>=11.3.7 in c:\users\janet\documents\vigimed\vigimed\.venv\lib\site-packages (from jupysql) (27.10.0)
# Requirement already satisfied: jupysql-plugin>=0.4.2 in c:\users\janet\documents\vigimed\vigimed\.venv\lib\site-packages (from jupysql) (0.4.5)
# Requirement already satisfied: ploomber-core>=0.2.7 in c:\users\janet\documents\vigimed\vigimed\.venv\lib\site-packages (from jupysql) (0.2.27)
# Requirement already satisfied: pyyaml in c:\users\janet\documents\vigimed\vigimed\.venv\lib\site-packages (from ploomber-core>=0.2.7->jupysql) (6.0.2)
# Requirement already satisfied: posthog>=3.0 in c:\users\janet\documents\vigimed\vigimed\.venv\lib\site-packages (from ploomber-core>=0.2.7->jupysql) (6.7.0)
# Requirement already satisfied: requests<3.0,>=2.7 in c:\users\janet\documents\vigimed\vigimed\.venv\lib\site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.32.5)
# Requirement already satisfied: six>=1.5 in c:\users\janet\documents\vigimed\vigimed\.venv\lib\site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\janet\documents\vigimed\vigimed\.venv\lib\site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\janet\documents\vigimed\vigimed\.venv\lib\site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\janet\documents\vigimed\vigimed\.venv\lib\site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (1.9.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\janet\documents\vigimed\vigimed\.venv\lib\site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\janet\documents\vigimed\vigimed\.venv\lib\site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\janet\documents\vigimed\vigimed\.venv\lib\site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\janet\documents\vigimed\vigimed\.venv\lib\site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\janet\documents\vigimed\vigimed\.venv\lib\site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2025.8.3)
# Requirement already satisfied: wcwidth in c:\users\janet\documents\vigimed\vigimed\.venv\lib\site-packages (from prettytable>=3.12.0->jupysql) (0.2.13)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\janet\documents\vigimed\vigimed\.venv\lib\site-packages (from jinja2->jupysql) (3.0.2)
# Requirement already satisfied: greenlet>=1 in c:\users\janet\documents\vigimed\vigimed\.venv\lib\site-packages (from sqlalchemy->jupysql) (3.2.4)
# Using cached prettytable-3.16.0-py3-none-any.whl (33 kB)
# Installing collected packages: prettytable
#   Attempting uninstall: prettytable
#     Found existing installation: prettytable 3.10.0
#     Uninstalling prettytable-3.10.0:
#       Successfully uninstalled prettytable-3.10.0
# Successfully installed prettytable-3.16.0

# %%
import prettytable as pt, importlib, sys
print("prettytable", pt.__version__, pt.__file__)
[k for k in dir(pt) if k.isupper() and not k.startswith("_")]
# Out:
# prettytable 3.16.0 c:\Users\janet\Documents\VigiMed\vigimed\.venv\lib\site-packages\prettytable\__init__.py
# []

# %%
import sys
sys.path.append('../../src/')

# %%
# %run ../config/bootstrap.py
from utils import get_project_root
import duckdb
project_root = get_project_root() 
import sys
sys.path.append(project_root)

# %%
# %load_ext sql
# %config SqlMagic.autopandas = True
# %config SqlMagic.displaylimit = 100
# %config SqlMagic.style = "PLAIN_COLUMNS"
# %sql duckdb:///:memory:
# Out:
# Connecting to 'duckdb:///:memory:'

# %% [markdown]
# # Create Tables

# %%
# %sql ROLLBACK;
# Out:
# Running query in 'duckdb:///:memory:'
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%sql
# DROP TABLE IF EXISTS dim_notificacoes;
# CREATE TABLE dim_notificacoes AS
# SELECT * FROM read_parquet('../data/03_gold/dim_notificacoes/dim_notificacoes.parquet');
# Out:
# Running query in 'duckdb:///:memory:'
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %sql ROLLBACK;
# Out:
# Running query in 'duckdb:///:memory:'
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%sql
# DROP TABLE IF EXISTS fat_notificacoes_medicamentos;
# CREATE TABLE fat_notificacoes_medicamentos AS
# SELECT * FROM read_parquet('../data/03_gold/fat_notificacoes_medicamentos/fat_notificacoes_medicamentos.parquet');
# Out:
# Running query in 'duckdb:///:memory:'
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %sql ROLLBACK;
# Out:
# Running query in 'duckdb:///:memory:'
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%sql
# DROP TABLE IF EXISTS fat_notificacoes_reacoes;
# CREATE TABLE fat_notificacoes_reacoes AS
# SELECT * FROM read_parquet('../data/03_gold/fat_notificacoes_reacoes/fat_notificacoes_reacoes.parquet');
# Out:
# Running query in 'duckdb:///:memory:'
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %sql ROLLBACK;
# Out:
# Running query in 'duckdb:///:memory:'
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%sql
# DROP TABLE IF EXISTS dim_atc;
# CREATE TABLE dim_atc AS
# SELECT * FROM read_parquet('../data/03_gold/dim_atc/dim_atc.parquet');
# Out:
# Running query in 'duckdb:///:memory:'
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %sql ROLLBACK;
# Out:
# Running query in 'duckdb:///:memory:'
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%sql
# DROP TABLE IF EXISTS dim_soc;
# CREATE TABLE dim_soc AS
# SELECT * FROM read_parquet('../data/03_gold/dim_soc/dim_soc.parquet');
# Out:
# Running query in 'duckdb:///:memory:'
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%sql
# select * from dim_notificacoes limit 5;
# Out:
# Running query in 'duckdb:///:memory:'
#    PK_NOTIFICACAO  UF UF_VALOR UF_DESCRICAO  TIPO_ENTRADA_VIGIMED  \
# 0               1  25       SP    SAO PAULO                     2
# 1               2  25       SP    SAO PAULO                     2
# 2               3  25       SP    SAO PAULO                     2
# 3               4  25       SP    SAO PAULO                     6
# 4               5  25       SP    SAO PAULO                     2
#
#           TIPO_ENTRADA_VIGIMED_VALOR  RECEBIDO_DE     RECEBIDO_DE_VALOR  \
# 0             EMPRESAS FARMACEUTICAS            5  EMPRESA FARMACEUTICA
# 1             EMPRESAS FARMACEUTICAS            5  EMPRESA FARMACEUTICA
# 2             EMPRESAS FARMACEUTICAS            5  EMPRESA FARMACEUTICA
# 3  EREPORTING - INDUSTRIA, CARGA E2B            5  EMPRESA FARMACEUTICA
# 4             EMPRESAS FARMACEUTICAS            5  EMPRESA FARMACEUTICA
#
#   IDENTIFICACAO_NOTIFICACAO DATA_INCLUSAO_SISTEMA DATA_ULTIMA_ATUALIZACAO  \
# 0       BR-ANVISA-300212656            2023-09-28              2023-09-28
# 1       BR-ANVISA-300208322            2023-09-01              2023-09-01
# 2       BR-ANVISA-300214015            2023-10-06              2023-10-06
# 3       BR-ANVISA-300345102            2025-07-21              2025-07-21
# 4       BR-ANVISA-300212385            2023-09-27              2023-09-27
#
#   DATA_NOTIFICACAO  TIPO_NOTIFICACAO  TIPO_NOTIFICACAO_VALOR  \
# 0              NaT                 1  NOTIFICACAO ESPONTANEA
# 1              NaT                 1  NOTIFICACAO ESPONTANEA
# 2              NaT                 1  NOTIFICACAO ESPONTANEA
# 3              NaT                 1  NOTIFICACAO ESPONTANEA
# 4              NaT                 1  NOTIFICACAO ESPONTANEA
#
#    NOTIFICACAO_PARENT_CHILD NOTIFICACAO_PARENT_CHILD_VALOR DATA_NASCIMENTO  \
# 0                         0                  NAO INFORMADO      1990-01-31
# 1                         0                  NAO INFORMADO             NaT
# 2                         0                  NAO INFORMADO      1971-05-22
# 3                         0                  NAO INFORMADO      1974-11-23
# 4                         0                  NAO INFORMADO             NaT
#
#    IDADE_MOMENTO_REACAO_VALOR IDADE_MOMENTO_REACAO_UNIDADE  GRUPO_IDADE  \
# 0                          30                       ANO(S)            0
# 1                           0                 DESCONHECIDO            0
# 2                          49                       ANO(S)            0
# 3                          46                       ANO(S)            0
# 4                           0                 DESCONHECIDO            0
#
#   GRUPO_IDADE_VALOR GRUPO_IDADE_DESCRICAO  \
# 0      DESCONHECIDO          DESCONHECIDO
# 1      DESCONHECIDO          DESCONHECIDO
# 2      DESCONHECIDO          DESCONHECIDO
# 3      DESCONHECIDO          DESCONHECIDO
# 4      DESCONHECIDO          DESCONHECIDO
#
#    IDADE_GESTACIONAL_MOMENTO_REACAO_VALOR  \
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       0
# 4                                       0
#
#   IDADE_GESTACIONAL_MOMENTO_REACAO_UNIDADE  SEXO SEXO_VALOR  GESTANTE  \
# 0                             DESCONHECIDO     1   FEMININO         2
# 1                             DESCONHECIDO     1   FEMININO         2
# 2                             DESCONHECIDO     2  MASCULINO         2
# 3                             DESCONHECIDO     2  MASCULINO         2
# 4                             DESCONHECIDO     2  MASCULINO         2
#
#   GESTANTE_VALOR  LACTANTE LACTANTE_VALOR       PESO_KG     ALTURA_CM  \
# 0            NAO         2            NAO          68.0           165
# 1            NAO         2            NAO  DESCONHECIDO  DESCONHECIDO
# 2            NAO         2            NAO  DESCONHECIDO  DESCONHECIDO
# 3            NAO         2            NAO  DESCONHECIDO  DESCONHECIDO
# 4            NAO         2            NAO  DESCONHECIDO  DESCONHECIDO
#
#   REACAO_EVENTO_ADVERSO_MEDDRA  GRAVE GRAVE_VALOR  GRAVIDADE  \
# 0                  HEMIPARESIA      1         SIM          1
# 1                     CEFALEIA      2         NAO          1
# 2                 NEFROLITIASE      1         SIM          2
# 3           CHOQUE ANAFILATICO      1         SIM          3
# 4               ABSCESSO NASAL      1         SIM          1
#
#                            GRAVIDADE_VALOR  DESFECHO DESFECHO_VALOR  \
# 0  OUTRO EFEITO CLINICAMENTE SIGNIFICATIVO         1     RECUPERADO
# 1  OUTRO EFEITO CLINICAMENTE SIGNIFICATIVO         2   DESCONHECIDO
# 2                           HOSPITALIZACAO         2   DESCONHECIDO
# 3                            AMEACA R VIDA         2   DESCONHECIDO
# 4  OUTRO EFEITO CLINICAMENTE SIGNIFICATIVO         2   DESCONHECIDO
#
#   DATA_INICIO_HORA DATA_FINAL_HORA  DURACAO_VALOR DURACAO_UNIDADE  \
# 0       2021-01-25      2021-02-06             12          DIA(S)
# 1       2021-01-22             NaT              0    DESCONHECIDO
# 2       2021-02-03             NaT              0    DESCONHECIDO
# 3       2021-03-02             NaT              0    DESCONHECIDO
# 4              NaT             NaT              0    DESCONHECIDO
#
#    RELACAO_MEDICAMENTO_EVENTO RELACAO_MEDICAMENTO_EVENTO_VALOR  \
# 0                           2                     CONCOMITANTE
# 1                           1                         SUSPEITO
# 2                           2                     CONCOMITANTE
# 3                           1                         SUSPEITO
# 4                           1                         SUSPEITO
#
#                 NOME_MEDICAMENTO_WHODRUG  ACAO_ADOTADA ACAO_ADOTADA_VALOR  \
# 0                                 TAMISA             3      NAO APLICAVEL
# 1                              CORONAVAC             3      NAO APLICAVEL
# 2                             METFORMINA             2       DESCONHECIDO
# 3      SORO ANTIBOTROPICO (PENTAVALENTE)             2       DESCONHECIDO
# 4  VACINA ADSORVIDA COVID-19 (INATIVADA)             2       DESCONHECIDO
#
#    NOTIFICADOR                              NOTIFICADOR_VALOR  \
# 0            4                                         MEDICO
# 1            2  CONSUMIDOR OU OUTRO NAO PROFISSIONAL DE SAUDE
# 2            4                                         MEDICO
# 3            3                                   FARMACEUTICO
# 4            2  CONSUMIDOR OU OUTRO NAO PROFISSIONAL DE SAUDE
#
#                                                                HASH  \
# 0  35cb7fb032989ed964911f71a7f71e660476984c53030f0f040a899732bfd63d
# 1  bef737a8ddcded5ede938b991a19f16b6546081b16df8248201e0284a491dbbd
# 2  f2b5a4e2b8a3495b0addc13f1401bde6ced80317afb546795f177b0acf948701
# 3  cfb2b052c12cbf900a894b94a7573ea7323d28b3c99455a4330ffa8adee0c0ff
# 4  0cd029bb9e8b797620238822ce1832f78036ec9b141c93d576d67937f68194fe
#
#   VALIDADE_REGISTRO_INICIAL VALIDADE_REGISTRO_FINAL ATUALIZADO_EM  FLAG_ATUAL
# 0                2025-11-17              9999-12-31    2025-11-17        True
# 1                2025-11-17              9999-12-31    2025-11-17        True
# 2                2025-11-17              9999-12-31    2025-11-17        True
# 3                2025-11-17              9999-12-31    2025-11-17        True
# 4                2025-11-17              9999-12-31    2025-11-17        True

# %%
# %%sql
# select SEXO_VALOR, count(*) from dim_notificacoes
# group by 1;
# Out:
# Running query in 'duckdb:///:memory:'
#      SEXO_VALOR  count_star()
# 0  DESCONHECIDO         11801
# 1     MASCULINO        104452
# 2      FEMININO        173642

# %%
# %%sql
# SELECT * FROM dim_atc;
# Out:
# Running query in 'duckdb:///:memory:'
#     PK_ATC           DESCRICAO
# 0   outros              outros
# 1  L01FA01           RITUXIMAB
# 2  L04AA24           ABATACEPT
# 3  L04AB04          ADALIMUMAB
# 4  L04AB05  CERTOLIZUMAB PEGOL
# 5  L04AB01          ETANERCEPT
# 6  L04AB06           GOLIMUMAB
# 7  L04AB02          INFLIXIMAB
# 8  L04AC07         TOCILIZUMAB

# %%
# %%sql
# select * from fat_notificacoes_medicamentos limit 5;
# Out:
# Running query in 'duckdb:///:memory:'
#   IDENTIFICACAO_NOTIFICACAO RELACAO_MEDICAMENTO_EVENTO DETENTOR_REGISTRO  \
# 0       BR-ANVISA-300000004                   Suspeito             Teuto
# 1       BR-ANVISA-300000005                   Suspeito              None
# 2       BR-ANVISA-300000007                   Suspeito              None
# 3       BR-ANVISA-300000007                   Suspeito              None
# 4       BR-ANVISA-300000008                   Suspeito         Cristália
#
#   CONCENTRACAO COMPONENTE_SUSPEITO             ACAO_ADOTADA  \
# 0         None                None                     None
# 1         None                None  Retirada do medicamento
# 2         None                None  Retirada do medicamento
# 3         None                None  Retirada do medicamento
# 4         None                None                     None
#
#   PROBLEMAS_ADICIONAIS_RELCIONADOS_MEDICAMENTO INDICACAO_MEDDRA  \
# 0                                         None             None
# 1                                         None             None
# 2                                         None             None
# 3                                         None             None
# 4                                         None             None
#
#   INDICACAO_RELATADA_NOTIFICADOR_INICIAL                DOSE FREQUENCIA_DOSE  \
# 0                                   None  250 milligram (mg)          6 hora
# 1                                   None                None            None
# 2                                   None  250 milligram (mg)          6 hora
# 3                                   None                None            None
# 4                                   None                None            None
#
#               POSOLOGIA DURACAO INICIO_ADMINISTRACAO FIM_ADMINISTRACAO  \
# 0                  None   4 dia           2018-11-24               NaT
# 1                  None    None           2018-11-22        2018-11-22
# 2  250mg a cada 6 horas    None           2018-11-03        2018-11-15
# 3  100mg a cada 8 horas    None           2018-10-16        2018-11-15
# 4                  None    None           2018-10-24               NaT
#
#   FORMA_FARMACEUTICA    VIA_ADMINISTRACAO VIA_ADMINISTRACAO_MAE_PAI  \
# 0               None  infusão intravenosa                      None
# 1               None                 oral                      None
# 2               None                 oral                      None
# 3               None                 oral                      None
# 4               None  infusão intravenosa                      None
#
#   NUMELO_LOTE  PK_MEDICAMENTO  PK_ATC  ATIVO
# 0     5833018            9767  outros   True
# 1        None           16250  outros   True
# 2        None            5800  outros   True
# 3        None           16515  outros   True
# 4        None            5339  outros   True

# %%
# %%sql
# select * from fat_notificacoes_reacoes limit 5;
# Out:
# Running query in 'duckdb:///:memory:'
#   IDENTIFICACAO_NOTIFICACAO  PK_SOC DATA_INICIO_HORA DATA_FINAL_HORA DURACAO  \
# 0       BR-ANVISA-300000004    4113              NaT             NaT   3 dia
# 1       BR-ANVISA-300000005    9106       2018-11-22      2018-11-22    None
# 2       BR-ANVISA-300000007    3902       2018-11-15             NaT   2 dia
# 3       BR-ANVISA-300000008   11410       2018-10-25             NaT   5 dia
# 4       BR-ANVISA-300000010    1993              NaT             NaT    None
#
#   GRAVE                                       GRAVIDADE              DESFECHO
# 0   Não                                            None  Recuperado/Resolvido
# 1   Sim         Outro efeito clinicamente significativo  Recuperado/Resolvido
# 2   Sim         Outro efeito clinicamente significativo  Recuperado/Resolvido
# 3   Sim         Outro efeito clinicamente significativo  Recuperado/Resolvido
# 4   Sim  Hospitalização/Prolongamento de hospitalização  Recuperado/Resolvido

# %%
# %%sql
# select * from dim_soc limit 5;
# Out:
# Running query in 'duckdb:///:memory:'
#    PK_SOC                     SOC                            HLGT  \
# 0       0  Circunstâncias sociais  Fatores relacionados ao gênero
# 1       1  Circunstâncias sociais  Fatores relacionados ao gênero
# 2       2  Circunstâncias sociais  Fatores relacionados ao gênero
# 3       3  Circunstâncias sociais  Fatores relacionados ao gênero
# 4       4  Circunstâncias sociais    Fatores relacionados à idade
#
#                                       HLT                          PT  \
# 0  Circunstâncias relacionadas à gravidez                 Amamentação
# 1                 Questões de sexualidade          Abstinência sexual
# 2                 Questões de sexualidade  Atividade sexual aumentada
# 3                 Questões de sexualidade              Não consumação
# 4           Questões relacionadas à idade                        Bebê
#
#   REACAO_EVTO_ADVERSO_MEDDRA_LLT
# 0                    Amamentação
# 1             Abstinência sexual
# 2     Atividade sexual aumentada
# 3                 Não consumação
# 4                        Neonato

# %%
# %%sql
# select
# a.*
# ,b.*
# ,c.*
# ,dim_atc.descricao as medicamento
# ,dim_soc
# from dim_notificacoes as a
# inner join fat_notificacoes_medicamentos as b using(IDENTIFICACAO_NOTIFICACAO)
# inner join fat_notificacoes_reacoes as c using(IDENTIFICACAO_NOTIFICACAO)
# inner join dim_atc using(PK_ATC)
# inner join dim_soc using(PK_SOC)
# where dim_atc.DESCRICAO='RITUXIMAB'
# limit 10
# Out:
# Running query in 'duckdb:///:memory:'
#    PK_NOTIFICACAO  UF      UF_VALOR       UF_DESCRICAO  TIPO_ENTRADA_VIGIMED  \
# 0           92054   5            BA              BAHIA                     1
# 1           92054   5            BA              BAHIA                     1
# 2           92055  21            RS  RIO GRANDE DO SUL                     1
# 3            3832   0  DESCONHECIDO       DESCONHECIDO                     2
# 4            3832   0  DESCONHECIDO       DESCONHECIDO                     2
# 5            3832   0  DESCONHECIDO       DESCONHECIDO                     2
# 6            3832   0  DESCONHECIDO       DESCONHECIDO                     2
# 7            3832   0  DESCONHECIDO       DESCONHECIDO                     2
# 8            3832   0  DESCONHECIDO       DESCONHECIDO                     2
# 9            3812   0  DESCONHECIDO       DESCONHECIDO                     2
#
#   TIPO_ENTRADA_VIGIMED_VALOR  RECEBIDO_DE  \
# 0          SERVICOS DE SAUDE            4
# 1          SERVICOS DE SAUDE            4
# 2          SERVICOS DE SAUDE            8
# 3     EMPRESAS FARMACEUTICAS            5
# 4     EMPRESAS FARMACEUTICAS            5
# 5     EMPRESAS FARMACEUTICAS            5
# 6     EMPRESAS FARMACEUTICAS            5
# 7     EMPRESAS FARMACEUTICAS            5
# 8     EMPRESAS FARMACEUTICAS            5
# 9     EMPRESAS FARMACEUTICAS            5
#
#                       RECEBIDO_DE_VALOR IDENTIFICACAO_NOTIFICACAO  \
# 0  CENTRO REGIONAL DE FARMACOVIGILANCIA       BR-ANVISA-300121951
# 1  CENTRO REGIONAL DE FARMACOVIGILANCIA       BR-ANVISA-300121951
# 2                 PROFISSIONAL DE SAUDE       BR-ANVISA-300121952
# 3                  EMPRESA FARMACEUTICA       BR-ANVISA-300121981
# 4                  EMPRESA FARMACEUTICA       BR-ANVISA-300121981
# 5                  EMPRESA FARMACEUTICA       BR-ANVISA-300121981
# 6                  EMPRESA FARMACEUTICA       BR-ANVISA-300121981
# 7                  EMPRESA FARMACEUTICA       BR-ANVISA-300121981
# 8                  EMPRESA FARMACEUTICA       BR-ANVISA-300121981
# 9                  EMPRESA FARMACEUTICA       BR-ANVISA-300121997
#
#   DATA_INCLUSAO_SISTEMA DATA_ULTIMA_ATUALIZACAO DATA_NOTIFICACAO  \
# 0            2022-03-14              2022-03-14       2022-03-04
# 1            2022-03-14              2022-03-14       2022-03-04
# 2            2022-03-14              2022-03-14       2022-03-11
# 3            2022-03-14              2022-03-24              NaT
# 4            2022-03-14              2022-03-24              NaT
# 5            2022-03-14              2022-03-24              NaT
# 6            2022-03-14              2022-03-24              NaT
# 7            2022-03-14              2022-03-24              NaT
# 8            2022-03-14              2022-03-24              NaT
# 9            2022-03-14              2022-03-14              NaT
#
#    TIPO_NOTIFICACAO  TIPO_NOTIFICACAO_VALOR  NOTIFICACAO_PARENT_CHILD  \
# 0                 1  NOTIFICACAO ESPONTANEA                         0
# 1                 1  NOTIFICACAO ESPONTANEA                         0
# 2                 1  NOTIFICACAO ESPONTANEA                         0
# 3                 1  NOTIFICACAO ESPONTANEA                         0
# 4                 1  NOTIFICACAO ESPONTANEA                         0
# 5                 1  NOTIFICACAO ESPONTANEA                         0
# 6                 1  NOTIFICACAO ESPONTANEA                         0
# 7                 1  NOTIFICACAO ESPONTANEA                         0
# 8                 1  NOTIFICACAO ESPONTANEA                         0
# 9                 1  NOTIFICACAO ESPONTANEA                         0
#
#   NOTIFICACAO_PARENT_CHILD_VALOR DATA_NASCIMENTO  IDADE_MOMENTO_REACAO_VALOR  \
# 0                  NAO INFORMADO      1981-08-05                          40
# 1                  NAO INFORMADO      1981-08-05                          40
# 2                  NAO INFORMADO      1944-08-10                          77
# 3                  NAO INFORMADO      1967-02-18                           0
# 4                  NAO INFORMADO      1967-02-18                           0
# 5                  NAO INFORMADO      1967-02-18                           0
# 6                  NAO INFORMADO      1967-02-18                           0
# 7                  NAO INFORMADO      1967-02-18                           0
# 8                  NAO INFORMADO      1967-02-18                           0
# 9                  NAO INFORMADO             NaT                          68
#
#   IDADE_MOMENTO_REACAO_UNIDADE  GRUPO_IDADE GRUPO_IDADE_VALOR  \
# 0                       ANO(S)            6            ADULTO
# 1                       ANO(S)            6            ADULTO
# 2                       ANO(S)            7             IDOSO
# 3                 DESCONHECIDO            0      DESCONHECIDO
# 4                 DESCONHECIDO            0      DESCONHECIDO
# 5                 DESCONHECIDO            0      DESCONHECIDO
# 6                 DESCONHECIDO            0      DESCONHECIDO
# 7                 DESCONHECIDO            0      DESCONHECIDO
# 8                 DESCONHECIDO            0      DESCONHECIDO
# 9                       ANO(S)            0      DESCONHECIDO
#
#   GRUPO_IDADE_DESCRICAO  IDADE_GESTACIONAL_MOMENTO_REACAO_VALOR  \
# 0          19 A 59 ANOS                                       0
# 1          19 A 59 ANOS                                       0
# 2       60 ANOS OU MAIS                                       0
# 3          DESCONHECIDO                                       0
# 4          DESCONHECIDO                                       0
# 5          DESCONHECIDO                                       0
# 6          DESCONHECIDO                                       0
# 7          DESCONHECIDO                                       0
# 8          DESCONHECIDO                                       0
# 9          DESCONHECIDO                                       0
#
#   IDADE_GESTACIONAL_MOMENTO_REACAO_UNIDADE  SEXO SEXO_VALOR  GESTANTE  \
# 0                             DESCONHECIDO     1   FEMININO         0
# 1                             DESCONHECIDO     1   FEMININO         0
# 2                             DESCONHECIDO     1   FEMININO         0
# 3                             DESCONHECIDO     2  MASCULINO         0
# 4                             DESCONHECIDO     2  MASCULINO         0
# 5                             DESCONHECIDO     2  MASCULINO         0
# 6                             DESCONHECIDO     2  MASCULINO         0
# 7                             DESCONHECIDO     2  MASCULINO         0
# 8                             DESCONHECIDO     2  MASCULINO         0
# 9                             DESCONHECIDO     2  MASCULINO         0
#
#   GESTANTE_VALOR  LACTANTE LACTANTE_VALOR       PESO_KG     ALTURA_CM  \
# 0  NAO INFORMADO         0  NAO INFORMADO  DESCONHECIDO  DESCONHECIDO
# 1  NAO INFORMADO         0  NAO INFORMADO  DESCONHECIDO  DESCONHECIDO
# 2  NAO INFORMADO         0  NAO INFORMADO          49.1  DESCONHECIDO
# 3  NAO INFORMADO         0  NAO INFORMADO          63.2           170
# 4  NAO INFORMADO         0  NAO INFORMADO          63.2           170
# 5  NAO INFORMADO         0  NAO INFORMADO          63.2           170
# 6  NAO INFORMADO         0  NAO INFORMADO          63.2           170
# 7  NAO INFORMADO         0  NAO INFORMADO          63.2           170
# 8  NAO INFORMADO         0  NAO INFORMADO          63.2           170
# 9  NAO INFORMADO         0  NAO INFORMADO         94.10  DESCONHECIDO
#
#   REACAO_EVENTO_ADVERSO_MEDDRA  GRAVE GRAVE_VALOR  GRAVIDADE  \
# 0                   DOR LOMBAR      2         NAO          0
# 1                   DOR LOMBAR      2         NAO          0
# 2              ERUPCAO CUTANEA      2         NAO          0
# 3                    HIPOXEMIA      1         SIM          1
# 4                    HIPOXEMIA      1         SIM          1
# 5                    HIPOXEMIA      1         SIM          1
# 6                    HIPOXEMIA      1         SIM          1
# 7                    HIPOXEMIA      1         SIM          1
# 8                    HIPOXEMIA      1         SIM          1
# 9                     CEFALEIA      1         SIM          1
#
#                            GRAVIDADE_VALOR  DESFECHO DESFECHO_VALOR  \
# 0                             DESCONHECIDO         1     RECUPERADO
# 1                             DESCONHECIDO         1     RECUPERADO
# 2                             DESCONHECIDO         1     RECUPERADO
# 3  OUTRO EFEITO CLINICAMENTE SIGNIFICATIVO         2   DESCONHECIDO
# 4  OUTRO EFEITO CLINICAMENTE SIGNIFICATIVO         2   DESCONHECIDO
# 5  OUTRO EFEITO CLINICAMENTE SIGNIFICATIVO         2   DESCONHECIDO
# 6  OUTRO EFEITO CLINICAMENTE SIGNIFICATIVO         2   DESCONHECIDO
# 7  OUTRO EFEITO CLINICAMENTE SIGNIFICATIVO         2   DESCONHECIDO
# 8  OUTRO EFEITO CLINICAMENTE SIGNIFICATIVO         2   DESCONHECIDO
# 9  OUTRO EFEITO CLINICAMENTE SIGNIFICATIVO         1     RECUPERADO
#
#   DATA_INICIO_HORA DATA_FINAL_HORA  DURACAO_VALOR DURACAO_UNIDADE  \
# 0       2021-09-13      2021-09-13              0    DESCONHECIDO
# 1       2021-09-13      2021-09-13              0    DESCONHECIDO
# 2              NaT      2022-03-11              0    DESCONHECIDO
# 3       2022-02-24      2022-02-24              1          DIA(S)
# 4       2022-02-24      2022-02-24              1          DIA(S)
# 5       2022-02-24      2022-02-24              1          DIA(S)
# 6       2022-02-24      2022-02-24              1          DIA(S)
# 7       2022-02-24      2022-02-24              1          DIA(S)
# 8       2022-02-24      2022-02-24              1          DIA(S)
# 9       2022-02-21      2022-02-21              0    DESCONHECIDO
#
#    RELACAO_MEDICAMENTO_EVENTO RELACAO_MEDICAMENTO_EVENTO_VALOR  \
# 0                           1                         SUSPEITO
# 1                           1                         SUSPEITO
# 2                           1                         SUSPEITO
# 3                           1                         SUSPEITO
# 4                           1                         SUSPEITO
# 5                           1                         SUSPEITO
# 6                           1                         SUSPEITO
# 7                           1                         SUSPEITO
# 8                           1                         SUSPEITO
# 9                           1                         SUSPEITO
#
#   NOME_MEDICAMENTO_WHODRUG  ACAO_ADOTADA       ACAO_ADOTADA_VALOR  \
# 0                  RIXIMYO             5  RETIRADA DO MEDICAMENTO
# 1                  RIXIMYO             5  RETIRADA DO MEDICAMENTO
# 2                 MABTHERA             5  RETIRADA DO MEDICAMENTO
# 3                RITUXIMAB             2             DESCONHECIDO
# 4                RITUXIMAB             2             DESCONHECIDO
# 5                RITUXIMAB             2             DESCONHECIDO
# 6                RITUXIMAB             2             DESCONHECIDO
# 7                RITUXIMAB             2             DESCONHECIDO
# 8                RITUXIMAB             2             DESCONHECIDO
# 9                  RIXIMYO             2             DESCONHECIDO
#
#    NOTIFICADOR NOTIFICADOR_VALOR  \
# 0            3      FARMACEUTICO
# 1            3      FARMACEUTICO
# 2            3      FARMACEUTICO
# 3            3      FARMACEUTICO
# 4            3      FARMACEUTICO
# 5            3      FARMACEUTICO
# 6            3      FARMACEUTICO
# 7            3      FARMACEUTICO
# 8            3      FARMACEUTICO
# 9            3      FARMACEUTICO
#
#                                                                HASH  \
# 0  522a7c970aee4e1aab9023e32a0e363c1612d2059689f7b8d7823d60062f96d6
# 1  522a7c970aee4e1aab9023e32a0e363c1612d2059689f7b8d7823d60062f96d6
# 2  3d51c18b51e02636680afb533e47774c01c6d6fc30e4b703152608dda7f3ae57
# 3  3697889742626335811cce5389e0026a0272b9c8136615e543b536b6f5b48563
# 4  3697889742626335811cce5389e0026a0272b9c8136615e543b536b6f5b48563
# 5  3697889742626335811cce5389e0026a0272b9c8136615e543b536b6f5b48563
# 6  3697889742626335811cce5389e0026a0272b9c8136615e543b536b6f5b48563
# 7  3697889742626335811cce5389e0026a0272b9c8136615e543b536b6f5b48563
# 8  3697889742626335811cce5389e0026a0272b9c8136615e543b536b6f5b48563
# 9  6a53509fb5226cbee06468cc85416830d25e96788a8db36a120f41d6e7cdc235
#
#   VALIDADE_REGISTRO_INICIAL VALIDADE_REGISTRO_FINAL ATUALIZADO_EM  FLAG_ATUAL  \
# 0                2025-11-17              9999-12-31    2025-11-17        True
# 1                2025-11-17              9999-12-31    2025-11-17        True
# 2                2025-11-17              9999-12-31    2025-11-17        True
# 3                2025-11-17              9999-12-31    2025-11-17        True
# 4                2025-11-17              9999-12-31    2025-11-17        True
# 5                2025-11-17              9999-12-31    2025-11-17        True
# 6                2025-11-17              9999-12-31    2025-11-17        True
# 7                2025-11-17              9999-12-31    2025-11-17        True
# 8                2025-11-17              9999-12-31    2025-11-17        True
# 9                2025-11-17              9999-12-31    2025-11-17        True
#
#   IDENTIFICACAO_NOTIFICACAO_1 RELACAO_MEDICAMENTO_EVENTO_1 DETENTOR_REGISTRO  \
# 0         BR-ANVISA-300121951                     Suspeito              None
# 1         BR-ANVISA-300121951                     Suspeito              None
# 2         BR-ANVISA-300121952                     Suspeito              None
# 3         BR-ANVISA-300121981                     Suspeito              None
# 4         BR-ANVISA-300121981                     Suspeito              None
# 5         BR-ANVISA-300121981                     Suspeito              None
# 6         BR-ANVISA-300121981                     Suspeito              None
# 7         BR-ANVISA-300121981                     Suspeito              None
# 8         BR-ANVISA-300121981                     Suspeito              None
# 9         BR-ANVISA-300121997                     Suspeito              None
#
#   CONCENTRACAO COMPONENTE_SUSPEITO           ACAO_ADOTADA_1  \
# 0      10mg/mL     Princípio Ativo  Retirada do medicamento
# 1      10mg/mL     Princípio Ativo  Retirada do medicamento
# 2     10 mg/mL                None  Retirada do medicamento
# 3         None                None             Desconhecido
# 4         None                None             Desconhecido
# 5         None                None             Desconhecido
# 6         None                None             Desconhecido
# 7         None                None             Desconhecido
# 8         None                None             Desconhecido
# 9         None                None             Desconhecido
#
#   PROBLEMAS_ADICIONAIS_RELCIONADOS_MEDICAMENTO  \
# 0                                         None
# 1                                         None
# 2                                         None
# 3                                         None
# 4                                         None
# 5                                         None
# 6                                         None
# 7                                         None
# 8                                         None
# 9                                         None
#
#                  INDICACAO_MEDDRA INDICACAO_RELATADA_NOTIFICADOR_INICIAL  \
# 0  Esclerose múltipla progressiva                                   None
# 1  Esclerose múltipla progressiva                                   None
# 2                   Quimioterapia                                   None
# 3                         Linfoma                               Lymphoma
# 4                         Linfoma                               Lymphoma
# 5                         Linfoma                               Lymphoma
# 6                         Linfoma                               Lymphoma
# 7                         Linfoma                               Lymphoma
# 8                         Linfoma                               Lymphoma
# 9           Linfoma (não-Hodgkin)          Linfoma folicular não Hodgkin
#
#                   DOSE FREQUENCIA_DOSE  \
# 0  1000 milligram (mg)       1 cíclico
# 1  1000 milligram (mg)       1 cíclico
# 2    43 milligram (mg)     1 por 1 dia
# 3   600 milligram (mg)
# 4   600 milligram (mg)
# 5   600 milligram (mg)
# 6   600 milligram (mg)
# 7   600 milligram (mg)
# 8   600 milligram (mg)
# 9   100 milligram (mg)
#
#                                        POSOLOGIA DURACAO INICIO_ADMINISTRACAO  \
# 0                                           None    None           2021-09-13
# 1                                           None    None           2021-09-13
# 2                                           None    None           2022-03-11
# 3  600 mg (8 cycles with an interval of 21 days)   1 dia           2022-02-24
# 4  600 mg (8 cycles with an interval of 21 days)   1 dia           2022-02-24
# 5  600 mg (8 cycles with an interval of 21 days)   1 dia           2022-02-24
# 6  600 mg (8 cycles with an interval of 21 days)   1 dia           2022-02-24
# 7  600 mg (8 cycles with an interval of 21 days)   1 dia           2022-02-24
# 8  600 mg (8 cycles with an interval of 21 days)   1 dia           2022-02-24
# 9                                           None    None                  NaT
#
#   FIM_ADMINISTRACAO                      FORMA_FARMACEUTICA  \
# 0               NaT  Concentrado para solução para perfusão
# 1               NaT  Concentrado para solução para perfusão
# 2        2022-03-11                           Frasco-ampola
# 3        2022-02-24   CONCENTRATE FOR SOLUTION FOR INFUSION
# 4        2022-02-24   CONCENTRATE FOR SOLUTION FOR INFUSION
# 5        2022-02-24   CONCENTRATE FOR SOLUTION FOR INFUSION
# 6        2022-02-24   CONCENTRATE FOR SOLUTION FOR INFUSION
# 7        2022-02-24   CONCENTRATE FOR SOLUTION FOR INFUSION
# 8        2022-02-24   CONCENTRATE FOR SOLUTION FOR INFUSION
# 9               NaT                                    None
#
#                 VIA_ADMINISTRACAO VIA_ADMINISTRACAO_MAE_PAI NUMELO_LOTE  \
# 0             infusão intravenosa                      None        None
# 1             infusão intravenosa                      None        None
# 2             infusão intravenosa                      None       H0331
# 3  intravenosa (não especificado)                      None       D4016
# 4  intravenosa (não especificado)                      None       D4016
# 5  intravenosa (não especificado)                      None       D4016
# 6  intravenosa (não especificado)                      None       D4016
# 7  intravenosa (não especificado)                      None       D4016
# 8  intravenosa (não especificado)                      None       D4016
# 9                      Endovenosa                      None      LM9736
#
#    PK_MEDICAMENTO   PK_ATC  ATIVO IDENTIFICACAO_NOTIFICACAO_2  PK_SOC  \
# 0           13173  L01FA01   True         BR-ANVISA-300121951     236
# 1           13173  L01FA01   True         BR-ANVISA-300121951    8230
# 2           13168  L01FA01   True         BR-ANVISA-300121952    4013
# 3           13171  L01FA01   True         BR-ANVISA-300121981    1211
# 4           13171  L01FA01   True         BR-ANVISA-300121981     259
# 5           13171  L01FA01   True         BR-ANVISA-300121981   11288
# 6           13171  L01FA01   True         BR-ANVISA-300121981    5930
# 7           13171  L01FA01   True         BR-ANVISA-300121981    6153
# 8           13171  L01FA01   True         BR-ANVISA-300121981   10705
# 9           13173  L01FA01   True         BR-ANVISA-300121997    3487
#
#   DATA_INICIO_HORA_1 DATA_FINAL_HORA_1 DURACAO_1 GRAVE_1  \
# 0         2021-09-13        2021-09-13      None     Não
# 1         2021-09-13        2021-09-13      None     Não
# 2                NaT        2022-03-11      None     Não
# 3         2022-02-24        2022-02-24     1 dia     Não
# 4         2022-02-24               NaT      None     Não
# 5         2022-02-24               NaT      None     Não
# 6         2022-02-24        2022-02-24     1 dia     Não
# 7         2022-02-24        2022-02-24     1 dia     Não
# 8         2022-02-24               NaT      None     Sim
# 9         2022-02-21        2022-02-21      None     Não
#
#                                GRAVIDADE_1            DESFECHO_1 medicamento  \
# 0                                     None  Recuperado/Resolvido   RITUXIMAB
# 1                                     None  Recuperado/Resolvido   RITUXIMAB
# 2                                     None  Recuperado/Resolvido   RITUXIMAB
# 3                                     None  Recuperado/Resolvido   RITUXIMAB
# 4                                     None          Desconhecido   RITUXIMAB
# 5                                     None          Desconhecido   RITUXIMAB
# 6                                     None  Recuperado/Resolvido   RITUXIMAB
# 7                                     None  Recuperado/Resolvido   RITUXIMAB
# 8  Outro efeito clinicamente significativo          Desconhecido   RITUXIMAB
# 9                                     None  Recuperado/Resolvido   RITUXIMAB
#
#                                                                                                                                                                                                                                                                                                 dim_soc
# 0                                                                                                    {'PK_SOC': 236, 'SOC': 'Distúrbios cardíacos', 'HLGT': 'Arritmias cardíacas', 'HLT': 'Distúrbios de frequência e ritmo NCO', 'PT': 'Bradicardia', 'REACAO_EVTO_ADVERSO_MEDDRA_LLT': 'Bradicardia'}
# 1  {'PK_SOC': 8230, 'SOC': 'Distúrbios musculoesqueléticos e do tecido conjuntivo', 'HLGT': 'Distúrbios musculoesqueléticos e do tecido conjuntivo NCO', 'HLT': 'Dor e desconforto musculoesqueléticos e do tecido conjuntivo', 'PT': 'Dor nas costas', 'REACAO_EVTO_ADVERSO_MEDDRA_LLT': 'Dor lombar'}
# 2                                                 {'PK_SOC': 4013, 'SOC': 'Distúrbios dos tecidos cutâneos e subcutâneos', 'HLGT': 'Quadros clínicos epidérmicos e dérmicos', 'HLT': 'Erupções cutâneas e exantemas NCO', 'PT': 'Erupção cutânea', 'REACAO_EVTO_ADVERSO_MEDDRA_LLT': 'Erupção cutânea'}
# 3                                                                                                                                 {'PK_SOC': 1211, 'SOC': 'Distúrbios do sistema nervoso', 'HLGT': 'Cefaleias', 'HLT': 'Cefaleias NCO', 'PT': 'Cefaleia', 'REACAO_EVTO_ADVERSO_MEDDRA_LLT': 'Cefaleia'}
# 4                                                                                                    {'PK_SOC': 259, 'SOC': 'Distúrbios cardíacos', 'HLGT': 'Arritmias cardíacas', 'HLT': 'Distúrbios de frequência e ritmo NCO', 'PT': 'Taquicardia', 'REACAO_EVTO_ADVERSO_MEDDRA_LLT': 'Taquicardia'}
# 5                                                                              {'PK_SOC': 11288, 'SOC': 'Distúrbios vasculares', 'HLGT': 'Distúrbios vasculares hipertensivos', 'HLT': 'Distúrbios vasculares hipertensivos NCO', 'PT': 'Hipertensão', 'REACAO_EVTO_ADVERSO_MEDDRA_LLT': 'Hipertensão'}
# 6                                                            {'PK_SOC': 5930, 'SOC': 'Distúrbios gerais e quadros clínicos no local de administração', 'HLGT': 'Distúrbios sistêmicos gerais NCO', 'HLT': 'Dor e desconforto NCO', 'PT': 'Dor', 'REACAO_EVTO_ADVERSO_MEDDRA_LLT': 'Dor corporal geral'}
# 7                                                         {'PK_SOC': 6153, 'SOC': 'Distúrbios gerais e quadros clínicos no local de administração', 'HLGT': 'Distúrbios sistêmicos gerais NCO', 'HLT': 'Sentimentos e sensações NCO', 'PT': 'Calafrios', 'REACAO_EVTO_ADVERSO_MEDDRA_LLT': 'Calafrios'}
# 8                                               {'PK_SOC': 10705, 'SOC': 'Distúrbios respiratórios, torácicos e do mediastino', 'HLGT': 'Distúrbios respiratórios NCO', 'HLT': 'Quadros clínicos associados a trocas gasosas anormais', 'PT': 'Hipóxia', 'REACAO_EVTO_ADVERSO_MEDDRA_LLT': 'Hipoxemia'}
# 9                                                                                                     {'PK_SOC': 3487, 'SOC': 'Distúrbios dos tecidos cutâneos e subcutâneos', 'HLGT': 'Angioedema e urticária', 'HLT': 'Urticárias', 'PT': 'Urticária', 'REACAO_EVTO_ADVERSO_MEDDRA_LLT': 'Urticária'}

# %%
# %%sql
# WITH populacao AS (
#   SELECT *,IDENTIFICACAO_NOTIFICACAO as id
#   FROM dim_notificacoes
#   WHERE sexo='MASCULINO' ---AND idade BETWEEN 18 AND 65
# ),
#  meds AS (
#   SELECT *,IDENTIFICACAO_NOTIFICACAO as id
#   FROM fat_notificacoes_medicamentos
#   inner join dim_atc using (PK_ATC)
#   inner join populacao using (IDENTIFICACAO_NOTIFICACAO)
#   WHERE dim_atc.DESCRICAO IN ('RITUXIMAB','EXEMPLO2')
# ),
#  rx_base AS (
#   SELECT *,IDENTIFICACAO_NOTIFICACAO as id,REACAO_EVTO_ADVERSO_MEDDRA_LLT as evento
#   FROM fat_notificacoes_reacoes
#   inner join populacao using (IDENTIFICACAO_NOTIFICACAO)
#   inner join dim_soc using(PK_SOC)
# ),
#  rx_pairs AS (
#   SELECT DISTINCT
#     mb.medicamento,
#     rb.evento,
#     COUNT(*) AS n_notificacoes
#   FROM meds mb
#   JOIN rx_base rb USING (id)
#   GROUP BY 1,2
# )
# select
# a.IDENTIFICACAO_NOTIFICACAO
# ,a.sexo
# ,a.DATA_INCLUSAO_SISTEMA
# ,b.PK_ATC
# ,dim_atc.descricao as medicamento
# ,dim_soc
# from dim_notificacoes as a
# inner join fat_notificacoes_medicamentos as b using(IDENTIFICACAO_NOTIFICACAO)
# inner join fat_notificacoes_reacoes as c using(IDENTIFICACAO_NOTIFICACAO)
# inner join dim_atc using(PK_ATC)
# inner join dim_soc using(PK_SOC)
# where dim_atc.DESCRICAO='RITUXIMAB'
# limit 10
# Out:
# Running query in 'duckdb:///:memory:'
#   IDENTIFICACAO_NOTIFICACAO  SEXO DATA_INCLUSAO_SISTEMA   PK_ATC medicamento  \
# 0       BR-ANVISA-300121951     1            2022-03-14  L01FA01   RITUXIMAB
# 1       BR-ANVISA-300121951     1            2022-03-14  L01FA01   RITUXIMAB
# 2       BR-ANVISA-300121952     1            2022-03-14  L01FA01   RITUXIMAB
# 3       BR-ANVISA-300121981     2            2022-03-14  L01FA01   RITUXIMAB
# 4       BR-ANVISA-300121981     2            2022-03-14  L01FA01   RITUXIMAB
# 5       BR-ANVISA-300121981     2            2022-03-14  L01FA01   RITUXIMAB
# 6       BR-ANVISA-300121981     2            2022-03-14  L01FA01   RITUXIMAB
# 7       BR-ANVISA-300121981     2            2022-03-14  L01FA01   RITUXIMAB
# 8       BR-ANVISA-300121981     2            2022-03-14  L01FA01   RITUXIMAB
# 9       BR-ANVISA-300121997     2            2022-03-14  L01FA01   RITUXIMAB
#
#                                                                                                                                                                                                                                                                                                 dim_soc
# 0                                                                                                    {'PK_SOC': 236, 'SOC': 'Distúrbios cardíacos', 'HLGT': 'Arritmias cardíacas', 'HLT': 'Distúrbios de frequência e ritmo NCO', 'PT': 'Bradicardia', 'REACAO_EVTO_ADVERSO_MEDDRA_LLT': 'Bradicardia'}
# 1  {'PK_SOC': 8230, 'SOC': 'Distúrbios musculoesqueléticos e do tecido conjuntivo', 'HLGT': 'Distúrbios musculoesqueléticos e do tecido conjuntivo NCO', 'HLT': 'Dor e desconforto musculoesqueléticos e do tecido conjuntivo', 'PT': 'Dor nas costas', 'REACAO_EVTO_ADVERSO_MEDDRA_LLT': 'Dor lombar'}
# 2                                                 {'PK_SOC': 4013, 'SOC': 'Distúrbios dos tecidos cutâneos e subcutâneos', 'HLGT': 'Quadros clínicos epidérmicos e dérmicos', 'HLT': 'Erupções cutâneas e exantemas NCO', 'PT': 'Erupção cutânea', 'REACAO_EVTO_ADVERSO_MEDDRA_LLT': 'Erupção cutânea'}
# 3                                                                                                                                 {'PK_SOC': 1211, 'SOC': 'Distúrbios do sistema nervoso', 'HLGT': 'Cefaleias', 'HLT': 'Cefaleias NCO', 'PT': 'Cefaleia', 'REACAO_EVTO_ADVERSO_MEDDRA_LLT': 'Cefaleia'}
# 4                                                                                                    {'PK_SOC': 259, 'SOC': 'Distúrbios cardíacos', 'HLGT': 'Arritmias cardíacas', 'HLT': 'Distúrbios de frequência e ritmo NCO', 'PT': 'Taquicardia', 'REACAO_EVTO_ADVERSO_MEDDRA_LLT': 'Taquicardia'}
# 5                                                                              {'PK_SOC': 11288, 'SOC': 'Distúrbios vasculares', 'HLGT': 'Distúrbios vasculares hipertensivos', 'HLT': 'Distúrbios vasculares hipertensivos NCO', 'PT': 'Hipertensão', 'REACAO_EVTO_ADVERSO_MEDDRA_LLT': 'Hipertensão'}
# 6                                                            {'PK_SOC': 5930, 'SOC': 'Distúrbios gerais e quadros clínicos no local de administração', 'HLGT': 'Distúrbios sistêmicos gerais NCO', 'HLT': 'Dor e desconforto NCO', 'PT': 'Dor', 'REACAO_EVTO_ADVERSO_MEDDRA_LLT': 'Dor corporal geral'}
# 7                                                         {'PK_SOC': 6153, 'SOC': 'Distúrbios gerais e quadros clínicos no local de administração', 'HLGT': 'Distúrbios sistêmicos gerais NCO', 'HLT': 'Sentimentos e sensações NCO', 'PT': 'Calafrios', 'REACAO_EVTO_ADVERSO_MEDDRA_LLT': 'Calafrios'}
# 8                                               {'PK_SOC': 10705, 'SOC': 'Distúrbios respiratórios, torácicos e do mediastino', 'HLGT': 'Distúrbios respiratórios NCO', 'HLT': 'Quadros clínicos associados a trocas gasosas anormais', 'PT': 'Hipóxia', 'REACAO_EVTO_ADVERSO_MEDDRA_LLT': 'Hipoxemia'}
# 9                                                                                                     {'PK_SOC': 3487, 'SOC': 'Distúrbios dos tecidos cutâneos e subcutâneos', 'HLGT': 'Angioedema e urticária', 'HLT': 'Urticárias', 'PT': 'Urticária', 'REACAO_EVTO_ADVERSO_MEDDRA_LLT': 'Urticária'}

# %% [markdown]
# ## Query Carol

# %%
# %%sql
# WITH
# populacao AS (
#   SELECT *,IDENTIFICACAO_NOTIFICACAO as id
#   FROM dim_notificacoes
#   WHERE sexo='MASCULINO' ---AND idade BETWEEN 18 AND 65
# ),
# meds AS (
#   SELECT *,IDENTIFICACAO_NOTIFICACAO as id
#   FROM fat_notificacoes_medicamentos
#   inner join dim_atc using (PK_ATC)
#   inner join populacao using (IDENTIFICACAO_NOTIFICACAO)
#   WHERE dim_atc.DESCRICAO IN ('RITUXIMAB','EXEMPLO2')
# ),
# rx_base AS (
#   SELECT *,IDENTIFICACAO_NOTIFICACAO as id,REACAO_EVTO_ADVERSO_MEDDRA_LLT as evento
#   FROM fat_notificacoes_reacoes
#   inner join populacao using (IDENTIFICACAO_NOTIFICACAO)
#   inner join dim_soc using(PK_SOC)
# ),
# rx_pairs AS (
#   SELECT DISTINCT
#     id,
#     evento
#   FROM rx_base
# ),
# event_soc AS (
#   SELECT evento, MIN(SOC) AS SOC
#   FROM rx_base
#   WHERE SOC IS NOT NULL
#   GROUP BY evento
# ),
# universe AS (
#   SELECT COUNT(DISTINCT id) AS total_ids
#   FROM rx_pairs
# ),
# event_ids AS (
#   SELECT evento, COUNT(DISTINCT id) AS total_ev_ids
#   FROM rx_pairs
#   GROUP BY evento
# ),
# exposed AS (
#   SELECT DISTINCT medicamento, id
#   FROM meds
# ),
# exposed_in_universe AS (
#   SELECT e.medicamento, e.id
#   FROM exposed e
#   JOIN (SELECT DISTINCT id FROM rx_pairs) u USING (id)
# ),
# N1_by_med AS (
#   SELECT medicamento, COUNT(DISTINCT id) AS N1
#   FROM exposed_in_universe
#   GROUP BY medicamento
# ),
# a_counts AS (
#   SELECT
#     eiu.medicamento,
#     r.evento,
#     COUNT(DISTINCT r.id) AS a
#   FROM exposed_in_universe eiu
#   JOIN rx_pairs r USING (id)
#   GROUP BY eiu.medicamento, r.evento
# ),
# med_event AS (
#   SELECT DISTINCT n.medicamento, e.evento
#   FROM N1_by_med n
#   CROSS JOIN event_ids e
# ),
# calc AS (
#   SELECT
#     me.medicamento,
#     es.SOC,
#     me.evento,
#     COALESCE(a.a, 0) AS a,
#     n.N1 AS N1,
#     (u.total_ids - n.N1) AS N0,
#     (e.total_ev_ids - COALESCE(a.a,0)) AS c,
#     (n.N1 - COALESCE(a.a,0)) AS b,
#     ((u.total_ids - n.N1) - (e.total_ev_ids - COALESCE(a.a,0))) AS d
#   FROM med_event me
#   JOIN N1_by_med n USING (medicamento)
#   JOIN event_ids e USING (evento)
#   CROSS JOIN universe u
#   LEFT JOIN a_counts a
#     ON a.medicamento = me.medicamento AND a.evento = me.evento
#   LEFT JOIN event_soc es
#     ON es.evento = me.evento
#   WHERE n.N1 > 0 AND (u.total_ids - n.N1) > 0
# ),
# final AS (
#   SELECT
#     medicamento,
#     SOC,
#     evento,
#     a, b, c, d,
#     N1 AS N_medicamento,
#     N0 AS N_outros,
#     CASE WHEN a=0 OR b=0 OR c=0 OR d=0 THEN a+0.5 ELSE a END AS A_,
#     CASE WHEN a=0 OR b=0 OR c=0 OR d=0 THEN b+0.5 ELSE b END AS B_,
#     CASE WHEN a=0 OR b=0 OR c=0 OR d=0 THEN c+0.5 ELSE c END AS C_,
#     CASE WHEN a=0 OR b=0 OR c=0 OR d=0 THEN d+0.5 ELSE d END AS D_
#   FROM calc
# )
# SELECT
#   medicamento,
#   SOC,
#   evento,
#   a, b, c, d,
#   N_medicamento,
#   N_outros,
#   (A_ * D_) / NULLIF(B_ * C_, 0)                                AS ROR,
#   EXP(LN((A_ * D_) / NULLIF(B_ * C_, 0)) - 1.96*SQRT(1/A_+1/B_+1/C_+1/D_)) AS IC95_low,
#   EXP(LN((A_ * D_) / NULLIF(B_ * C_, 0)) + 1.96*SQRT(1/A_+1/B_+1/C_+1/D_)) AS IC95_high,
#   CASE
#     WHEN a >= 3 /*min_cases*/
#      AND EXP(LN((A_ * D_) / NULLIF(B_ * C_, 0)) - 1.96*SQRT(1/A_+1/B_+1/C_+1/D_)) > 1.0
#     THEN TRUE ELSE FALSE
#   END AS sinal
# FROM final
# ORDER BY medicamento ASC, sinal DESC, ROR DESC, a DESC;
# Out:
# Running query in 'duckdb:///:memory:'
# RuntimeError: If using snippets, you may pass the --with argument explicitly.
# For more details please refer: https://jupysql.ploomber.io/en/latest/compose.html#with-argument
#
#
# Original error message from DB driver:
# (duckdb.duckdb.BinderException) Binder Error: Referenced column "medicamento" not found in FROM clause!
# Candidate bindings: "id"
#
# LINE 42:   SELECT DISTINCT medicamento, id
#                            ^
# [SQL: WITH
# populacao AS (
#   SELECT *,IDENTIFICACAO_NOTIFICACAO as id
#   FROM dim_notificacoes
#   WHERE sexo='MASCULINO'
# ),
# meds AS (
#   SELECT *,IDENTIFICACAO_NOTIFICACAO as id
#   FROM fat_notificacoes_medicamentos
#   inner join dim_atc using (PK_ATC)
#   inner join populacao using (IDENTIFICACAO_NOTIFICACAO)
#   WHERE dim_atc.DESCRICAO IN ('RITUXIMAB','EXEMPLO2')
# ),
# rx_base AS (
#   SELECT *,IDENTIFICACAO_NOTIFICACAO as id,REACAO_EVTO_ADVERSO_MEDDRA_LLT as evento
#   FROM fat_notificacoes_reacoes
#   inner join populacao using (IDENTIFICACAO_NOTIFICACAO)
#   inner join dim_soc using(PK_SOC)
# ),
# rx_pairs AS (
#   SELECT DISTINCT
#     id,
#     evento
#   FROM rx_base
# ),
# event_soc AS (
#   SELECT evento, MIN(SOC) AS SOC
#   FROM rx_base
#   WHERE SOC IS NOT NULL
#   GROUP BY evento
# ),
# universe AS (
#   SELECT COUNT(DISTINCT id) AS total_ids
#   FROM rx_pairs
# ),
# event_ids AS (
#   SELECT evento, COUNT(DISTINCT id) AS total_ev_ids
#   FROM rx_pairs
#   GROUP BY evento
# ),
# exposed AS (
#   SELECT DISTINCT medicamento, id
#   FROM meds
# ),
# exposed_in_universe AS (
#   SELECT e.medicamento, e.id
#   FROM exposed e
#   JOIN (SELECT DISTINCT id FROM rx_pairs) u USING (id)
# ),
# N1_by_med AS (
#   SELECT medicamento, COUNT(DISTINCT id) AS N1
#   FROM exposed_in_universe
#   GROUP BY medicamento
# ),
# a_counts AS (
#   SELECT
#     eiu.medicamento,
#     r.evento,
#     COUNT(DISTINCT r.id) AS a
#   FROM exposed_in_universe eiu
#   JOIN rx_pairs r USING (id)
#   GROUP BY eiu.medicamento, r.evento
# ),
# med_event AS (
#   SELECT DISTINCT n.medicamento, e.evento
#   FROM N1_by_med n
#   CROSS JOIN event_ids e
# ),
# calc AS (
#   SELECT
#     me.medicamento,
#     es.SOC,
#     me.evento,
#     COALESCE(a.a, 0) AS a,
#     n.N1 AS N1,
#     (u.total_ids - n.N1) AS N0,
#     (e.total_ev_ids - COALESCE(a.a,0)) AS c,
#     (n.N1 - COALESCE(a.a,0)) AS b,
#     ((u.total_ids - n.N1) - (e.total_ev_ids - COALESCE(a.a,0))) AS d
#   FROM med_event me
#   JOIN N1_by_med n USING (medicamento)
#   JOIN event_ids e USING (evento)
#   CROSS JOIN universe u
#   LEFT JOIN a_counts a
#     ON a.medicamento = me.medicamento AND a.evento = me.evento
#   LEFT JOIN event_soc es
#     ON es.evento = me.evento
#   WHERE n.N1 > 0 AND (u.total_ids - n.N1) > 0
# ),
# final AS (
#   SELECT
#     medicamento,
#     SOC,
#     evento,
#     a, b, c, d,
#     N1 AS N_medicamento,
#     N0 AS N_outros,
#     CASE WHEN a=0 OR b=0 OR c=0 OR d=0 THEN a+0.5 ELSE a END AS A_,
#     CASE WHEN a=0 OR b=0 OR c=0 OR d=0 THEN b+0.5 ELSE b END AS B_,
#     CASE WHEN a=0 OR b=0 OR c=0 OR d=0 THEN c+0.5 ELSE c END AS C_,
#     CASE WHEN a=0 OR b=0 OR c=0 OR d=0 THEN d+0.5 ELSE d END AS D_
#   FROM calc
# )
# SELECT
#   medicamento,
#   SOC,
#   evento,
#   a, b, c, d,
#   N_medicamento,
#   N_outros,
#   (A_ * D_) / NULLIF(B_ * C_, 0)                                AS ROR,
#   EXP(LN((A_ * D_) / NULLIF(B_ * C_, 0)) - 1.96*SQRT(1/A_+1/B_+1/C_+1/D_)) AS IC95_low,
#   EXP(LN((A_ * D_) / NULLIF(B_ * C_, 0)) + 1.96*SQRT(1/A_+1/B_+1/C_+1/D_)) AS IC95_high,
#   CASE
#     WHEN a >= 3
#      AND EXP(LN((A_ * D_) / NULLIF(B_ * C_, 0)) - 1.96*SQRT(1/A_+1/B_+1/C_+1/D_)) > 1.0
#     THEN TRUE ELSE FALSE
#   END AS sinal
# FROM final
# ORDER BY medicamento ASC, sinal DESC, ROR DESC, a DESC;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
