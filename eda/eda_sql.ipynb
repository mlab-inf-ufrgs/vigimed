# %% [markdown]
# ## Exploratory Data Analysis - EDA

# %% [markdown]
# # Setup
#
# ```python
# !git clone --depth=1 https://github.com/mlab-inf-ufrgs/vigimed.git
#
# !pip -q install duckdb ipython-sql duckdb-engine sqlalchemy
# ```

# %%
from pathlib import Path
path = Path("C:/Users/silma/Projetos/vigimed/data/03_gold")

# %%
# %load_ext sql
# %config SqlMagic.autopandas = True
# %config SqlMagic.displaylimit = 100
# %config SqlMagic.named_parameters = "enabled"
# %config SqlMagic.autocommit = True

# Banco em arquivo (persiste durante a sessão).
#%sql duckdb:///content/vigimed.duckdb
# Se preferir memória: 
# %sql duckdb:///:memory:
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql ROLLBACK;
# Out:
# Running query in 'duckdb:///:memory:'
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
from pathlib import Path
path = Path("C:/Users/silma/Projetos/vigimed/data/03_gold")
path_dim_notificacoes = path / 'dim_notificacoes' / 'dim_notificacoes.parquet'
path_fat_notificacoes_medicamentos = path / 'fat_notificacoes_medicamentos' / 'fat_notificacoes_medicamentos.csv'
path_fat_notificacoes_reacoes = path / 'fat_notificacoes_reacoes' / 'fat_notificacoes_reacoes.csv'
path_dim_atc = path / 'dim_atc' / 'dim_atc.csv'
path_dim_soc = path / 'dim_soc' / 'dim_soc.csv'

# %%
# %%sql
# DROP TABLE IF EXISTS dim_notificacoes;
# CREATE TABLE dim_notificacoes AS
# SELECT * FROM read_csv_auto('c:/Users/silma/Projetos/vigimed/data/03_gold/dim_notificacoes/dim_notificacoes.parquet');
# Out:
# Running query in 'duckdb:///:memory:'
# RuntimeError: (_duckdb.TransactionException) TransactionContext Error: Current transaction is aborted (please ROLLBACK)
# [SQL: DROP TABLE IF EXISTS dim_notificacoes;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %%sql
# DROP TABLE IF EXISTS dim_notificacoes;
# CREATE TABLE dim_notificacoes AS
# SELECT * FROM read_csv_auto('c:/Users/silma/Projetos/vigimed/data/03_gold/dim_notificacoes/dim_notificacoes.parquet');
#
# --------------------------------------------------------------------------------------------------------------------
# DROP TABLE IF EXISTS fat_medicamentos;
# CREATE TABLE fat_medicamentos AS
# SELECT * FROM read_csv_auto('c:/Users/silma/Projetos/vigimed/data/03_gold/fat_notificacoes_medicamentos/fat_notificacoes_medicamentos.csv');
#
# --------------------------------------------------------------------------------------------------------------------
# DROP TABLE IF EXISTS fat_reacoes;
# CREATE TABLE fat_reacoes AS
# SELECT * FROM read_csv_auto('c:/Users/silma/Projetos/vigimed/data/03_gold/fat_notificacoes_reacoes/fat_notificacoes_reacoes.csv');
#
# --------------------------------------------------------------------------------------------------------------------
# DROP TABLE IF EXISTS dim_atc;
# CREATE TABLE dim_atc AS
# SELECT * FROM read_csv_auto('c:/Users/silma/Projetos/vigimed/data/03_gold/dim_atc/dim_atc.csv');
#
# --------------------------------------------------------------------------------------------------------------------
# DROP TABLE IF EXISTS dim_soc;
# CREATE TABLE dim_soc AS
# SELECT * FROM read_csv_auto('c:/Users/silma/Projetos/vigimed/data/03_gold/dim_soc/dim_soc.parquet');
# Out:
# Running query in 'duckdb:///:memory:'
# RuntimeError: (_duckdb.InvalidInputException) Invalid Input Error: Error when sniffing file "c:/Users/silma/Projetos/vigimed/data/03_gold/fat_notificacoes_medicamentos/fat_notificacoes_medicamentos.csv".
# It was not possible to automatically detect the CSV parsing dialect
# The search space used was:
# Delimiter Candidates: ',', '|', ';', '	'
# Quote/Escape Candidates: ['(no quote)','(no escape)'],['"','(no escape)'],['"','"'],['"','''],['"','\'],[''','(no escape)'],[''','''],[''','"'],[''','\']
# Comment Candidates: '\0', '#'
# Encoding: utf-8
# Possible fixes:
# * Disable the parser's strict mode (strict_mode=false) to allow reading rows that do not comply with the CSV standard.
# * Make sure you are using the correct file encoding. If not, set it (e.g., encoding = 'utf-16').
# * Set delimiter (e.g., delim=',')
# * Set quote (e.g., quote='"')
# * Set escape (e.g., escape='"')
# * Set comment (e.g., comment='#')
# ...

# %%
# %%sql
# DROP TABLE IF EXISTS dim_soc;
# CREATE TABLE dim_soc AS
# SELECT * FROM read_csv_auto(path_dim_soc);
# Out:
# Running query in 'duckdb:///:memory:'
# RuntimeError: (_duckdb.IOException) IO Error: No files found that match the pattern "path_dim_soc"
#
# LINE 2: SELECT * FROM read_csv_auto(path_dim_soc);
#                       ^
# [SQL: CREATE TABLE dim_soc AS
# SELECT * FROM read_csv_auto(path_dim_soc);]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
