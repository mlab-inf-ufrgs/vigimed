# %% [markdown]
# ## Setup

# %%
import sys
sys.path.append('../../src/')


# %load_ext sql
# %config SqlMagic.autopandas = True
# %config SqlMagic.displaylimit = 100
# %config SqlMagic.named_parameters = "enabled"
# %config SqlMagic.autocommit = True

# Banco em arquivo (persiste durante a sessão).
#%sql duckdb:///content/vigimed.duckdb
# Se preferir memória: 
# %sql duckdb:///:memory:

#%run ../config/bootstrap.py
from utils import get_project_root
import duckdb
project_root = get_project_root() 
import sys
sys.path.append(project_root)
# Out:
# Connecting to 'duckdb:///:memory:'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 17
#      14 get_ipython().run_line_magic('sql', 'duckdb:///:memory:')
#      16 #%run ../config/bootstrap.py
# ---> 17 from utils import get_project_root
#      18 import duckdb
#      19 project_root = get_project_root()
#
# File ~/Área de trabalho/vigimed/eda/validacao_medicamentos/../../src/utils/__init__.py:5
#       3 from .atc_normalize import normalize_principio_ativo_atc
#       4 from .normalize import normalize_rows, normalize_date_column, mapping_column, duration_normalize, expandir_gravidade_wide
# ----> 5 from .forma_farmaceutica import _normalizar_basico, normalizar_forma_farmaceutica_raw, criar_dim_forma_farmaceutica
#
# File ~/Área de trabalho/vigimed/eda/validacao_medicamentos/../../src/utils/forma_farmaceutica.py:4
#       2 import pandas as pd
# ...

# %% [markdown]
# ## Atualizar a seção e abrir nova

# %%
# %sql ROLLBACK;
# Out:
# Running query in 'duckdb:///:memory:'
# Empty DataFrame
# Columns: [Success]
# Index: []

# %% [markdown]
# ## Criar as tabela e fazer as consultas

# %%
# %%sql
# DROP TABLE IF EXISTS dim_medicamentos;
# CREATE TABLE dim_medicamentos AS
# SELECT * FROM read_parquet('/home/carolina/Área de trabalho/vigimed/data/03_gold/dim_medicamentos/dim_medicamentos.parquet');
#
# DROP TABLE IF EXISTS dim_atc;
# CREATE TABLE dim_atc AS
# SELECT * FROM read_parquet('/home/carolina/Área de trabalho/vigimed/data/03_gold/dim_atc/dim_atc.parquet');
#
# DROP TABLE IF EXISTS dim_notificacoes;
# CREATE TABLE dim_notificacoes AS
# SELECT * FROM read_parquet('/home/carolina/Área de trabalho/vigimed/data/03_gold/dim_notificacoes/dim_notificacoes.parquet');
#
# DROP TABLE IF EXISTS dim_soc;
# CREATE TABLE dim_soc AS
# SELECT * FROM read_parquet('/home/carolina/Área de trabalho/vigimed/data/03_gold/dim_soc/dim_soc.parquet');
#
# DROP TABLE IF EXISTS fat_notificacoes_medicamentos;
# CREATE TABLE fat_notificacoes_medicamentos AS
# SELECT * FROM read_parquet('/home/carolina/Área de trabalho/vigimed/data/03_gold/fat_notificacoes_medicamentos');
#
# DROP TABLE IF EXISTS fat_notificacoes_reacoes;
# CREATE TABLE fat_notificacoes_reacoes AS
# SELECT * FROM read_parquet('/home/carolina/Área de trabalho/vigimed/data/03_gold/fat_notificacoes_reacoes/fat_notificacoes_reacoes.parquet');
# Out:
# Running query in 'duckdb:///:memory:'
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Empty DataFrame
# Columns: [Success]
# Index: []

# %% [markdown]
# ## ok  RELACAO_MEDICAMENTO_EVENTO

# %%
# %%sql
# SELECT RELACAO_MEDICAMENTO_EVENTO,count(*) as qt
# FROM dim_medicamentos
# GROUP BY 1
# ORDER BY qt DESC
# LIMIT 100;
# Out:
# Running query in 'duckdb:///:memory:'
#    RELACAO_MEDICAMENTO_EVENTO      qt
# 0                           1  375585
# 1                           2  165566
# 2                           3    8689
# 3                           4    2047
# 4                           0    1000

# %% [markdown]
# CONFIRMAÇÃO QUE NONE É NULL

# %%
# %%sql
# SELECT COUNT(*) AS qt_null
# FROM dim_medicamentos
# WHERE RELACAO_MEDICAMENTO_EVENTO IS NULL;
# Out:
# Running query in 'duckdb:///:memory:'
#    qt_null
# 0        0

# %% [markdown]
# ## ficou para carol  DETENTOR_REGISTRO

# %%
# %%sql
# SELECT DETENTOR_REGISTRO,count(*) as qt
# FROM dim_medicamentos
# GROUP BY 1
# ORDER BY qt DESC
# LIMIT 10;
# Out:
# Running query in 'duckdb:///:memory:'
#          DETENTOR_REGISTRO      qt
# 0             DESCONHECIDO  427446
# 1  NOVARTIS SECTOR: PHARMA    8539
# 2                CRISTALIA    6456
# 3       INSTITUTO BUTANTAN    4572
# 4                   PFIZER    4259
# 5             PFIZER, INC.    3705
# 6                EUROFARMA    3063
# 7                    LIBBS    2816
# 8            NOT SPECIFIED    2724
# 9                   BIOGEN    2545

# %%
# %%sql
#
# COPY (
# SELECT DETENTOR_REGISTRO,count(*) AS qt
# FROM dim_medicamentos
# GROUP BY 1
# ORDER BY qt DESC
# ) TO 'detentor_list.csv' (HEADER, DELIMITER ',');
# Out:
# Running query in 'duckdb:///:memory:'
# Empty DataFrame
# Columns: [Success]
# Index: []

# %% [markdown]
# CONFIRMAÇÃO QUE NONE É NULL

# %%
# %%sql
# SELECT COUNT(*) AS qt_null
# FROM dim_medicamentos
# WHERE DETENTOR_REGISTRO IS NULL;
# Out:
# Running query in 'duckdb:///:memory:'
#    qt_null
# 0        0

# %% [markdown]
# ## ficou para mel CONCENTRACAO

# %%
# %%sql
# SELECT CONCENTRACAO,count(*) as qt
# FROM dim_medicamentos
# GROUP BY 1
# ORDER BY qt DESC
# LIMIT 20;
# Out:
# Running query in 'duckdb:///:memory:'
#     CONCENTRACAO      qt
# 0   DESCONHECIDO  460269
# 1          100MG    3328
# 2          500MG    3161
# 3             1G    2892
# 4        10MG/ML    1976
# 5         500 MG    1888
# 6           50MG    1656
# 7         100 MG    1636
# 8           10MG    1420
# 9        50MG/ML    1314
# 10          20MG    1248
# 11          40MG    1187
# 12        150 MG    1118
# 13          5 MG    1103
# 14         15 MG    1032
# 15         50 MG    1018
# 16       20MG/ML     938
# 17           5MG     937
# 18         300MG     905
# 19      10 MG/ML     897

# %% [markdown]
# CONFIRMANDO QUE NONE  É  NULL

# %%
# %%sql
# SELECT COUNT(*) AS qt_null
# FROM dim_medicamentos
# WHERE CONCENTRACAO IS NULL;
# Out:
# Running query in 'duckdb:///:memory:'
#    qt_null
# 0        0

# %% [markdown]
# ## ok COMPONENTE_SUSPEITO

# %%
# %%sql
# SELECT COMPONENTE_SUSPEITO,count(*) as qt
# FROM dim_medicamentos
# GROUP BY 1
# ORDER BY qt DESC
# LIMIT 50;
# Out:
# Running query in 'duckdb:///:memory:'
#    COMPONENTE_SUSPEITO      qt
# 0                    0  496737
# 1                    1   55897
# 2                    2     127
# 3                    4      37
# 4                    5      32
# 5                    3      24
# 6                    7      11
# 7                    8       8
# 8                    6       7
# 9                    9       7

# %% [markdown]
# CONFIRMANDO QUE NONE  É  NULL

# %%
# %%sql
# SELECT COUNT(*) AS qt_null
# FROM dim_medicamentos
# WHERE COMPONENTE_SUSPEITO IS NULL;
# Out:
# Running query in 'duckdb:///:memory:'
#    qt_null
# 0        0

# %% [markdown]
# ## ok ACAO_ADOTADA

# %%
# %%sql
# SELECT ACAO_ADOTADA,count(*) as qt
# FROM dim_medicamentos
# GROUP BY 1
# ORDER BY qt DESC
# LIMIT 50;
# Out:
# Running query in 'duckdb:///:memory:'
#    ACAO_ADOTADA      qt
# 0             0  346766
# 1             1   85273
# 2             2   55618
# 3             3   52568
# 4             4    8202
# 5             5    4460

# %% [markdown]
# CONFIRMAÇÃO QUE  NONE   É NULL

# %%
# %%sql
# SELECT COUNT(*) AS qt_null
# FROM dim_medicamentos
# WHERE ACAO_ADOTADA IS NULL;
# Out:
# Running query in 'duckdb:///:memory:'
#    qt_null
# 0        0

# %%
534294/552887
# Out:
# 0.9663710667821815

# %% [markdown]
# ## ok - LISTA- PROBLEMAS_ADICIONAIS_RELCIONADOS_MEDICAMENTO

# %%
# %%sql
# SELECT PROBLEMAS_ADICIONAIS_RELCIONADOS_MEDICAMENTO,count(*) as qt
# FROM dim_medicamentos
# GROUP BY 1
# ORDER BY qt DESC
# LIMIT 50;
# Out:
# Running query in 'duckdb:///:memory:'
#                                                         PROBLEMAS_ADICIONAIS_RELCIONADOS_MEDICAMENTO  \
# 0                                                                                     [DESCONHECIDO]
# 1                                                                                [ERRO DE MEDICACAO]
# 2                                                                   [USO OFF-LABEL USO SEM REGISTRO]
# 3                                                       [LOTES TESTADOS E DENTRO DAS ESPECIFICACOES]
# 4                                                                                        [SUPERDOSE]
# 5                                                                                    [USO INCORRETO]
# 6                                                                 [ERRO DE MEDICACAO, USO INCORRETO]
# 7                                                [ERRO DE MEDICACAO, USO OFF-LABEL USO SEM REGISTRO]
# ...

# %%
# %%sql
#
# SELECT * FROM dim_medicamentos
# WHERE PROBLEMAS_ADICIONAIS_RELCIONADOS_MEDICAMENTO = 'SUPERDOSE|ERRO DE MEDICACAO|USO "OFF-LABEL" USO SEM REGISTRO'
# AND IDENTIFICACAO_NOTIFICACAO ='BR-ANVISA-300090408'
# Out:
# Running query in 'duckdb:///:memory:'
# RuntimeError: (_duckdb.ConversionException) Conversion Error: Type VARCHAR with value 'SUPERDOSE|ERRO DE MEDICACAO|USO "OFF-LABEL" USO SEM REGISTRO' can't be cast to the destination type VARCHAR[]
#
# LINE 2: WHERE PROBLEMAS_ADICIONAIS_RELCIONADOS_MEDICAMENTO = 'SUPERDOSE|ERRO DE MEDICACAO|USO "OFF-LABEL" USO SEM REGISTRO...
#                                                              ^
# [SQL: SELECT * FROM dim_medicamentos
# WHERE PROBLEMAS_ADICIONAIS_RELCIONADOS_MEDICAMENTO = 'SUPERDOSE|ERRO DE MEDICACAO|USO "OFF-LABEL" USO SEM REGISTRO'
# AND IDENTIFICACAO_NOTIFICACAO ='BR-ANVISA-300090408']
# (Background on this error at: https://sqlalche.me/e/20/9h9h)

# %%
# %%sql
#
# SELECT COUNT(*) FROM dim_medicamentos
# Out:
# Running query in 'duckdb:///:memory:'
#    count_star()
# 0        552887

# %% [markdown]
# CONFIRMANDO  QUE NONE  É NULL

# %%
# %%sql
# SELECT COUNT(*) AS qt_null
# FROM dim_medicamentos
# WHERE PROBLEMAS_ADICIONAIS_RELCIONADOS_MEDICAMENTO IS NULL;
# Out:
# Running query in 'duckdb:///:memory:'
#    qt_null
# 0   534294

# %% [markdown]
# ## ficou para sil INDICACAO_MEDDRA

# %%
# %%sql
#
# SELECT INDICACAO_MEDDRA,count(*) AS qt
# FROM dim_medicamentos
# GROUP BY 1
# ORDER BY qt DESC
# LIMIT 100;
# Out:
# Running query in 'duckdb:///:memory:'
#                                    INDICACAO_MEDDRA      qt
# 0                                      DESCONHECIDO  325534
# 1    USO DE MEDICAMENTO PARA INDICACAO DESCONHECIDA   19595
# 2         PRODUTO USADO PARA INDICACAO DESCONHECIDA   16515
# 3                                   DOENCA DE CROHN    6875
# 4                                ARTRITE REUMATOIDE    6207
# 5                                       HIPERTENSAO    4399
# 6                            PROFILAXIA DE COVID-19    4179
# 7                                ESCLEROSE MULTIPLA    4085
# 8                                  MIELOMA MULTIPLO    3449
# 9                          ESPONDILITE ANQUILOSANTE    3139
# 10                                   CANCER DE MAMA    3119
# 11                                              DOR    2982
# 12                                        ANALGESIA    2769
# 13                        NEOPLASIA MALIGNA DA MAMA    2694
# ...

# %% [markdown]
# CONFIRMANDO QUE NONE  É NULL

# %%
# %%sql
# SELECT COUNT(*) AS qt_null
# FROM dim_medicamentos
# WHERE INDICACAO_MEDDRA IS NULL;
# Out:
# Running query in 'duckdb:///:memory:'
#    qt_null
# 0        0

# %% [markdown]
# COPIAR PARA  CSV

# %%
# %%sql
#
# COPY (
# SELECT INDICACAO_MEDDRA,count(*) AS qt
# FROM dim_medicamentos
# GROUP BY 1
# ORDER BY qt DESC
# ) TO 'indicacao_meddra.csv' (HEADER, DELIMITER ',');
# Out:
# Running query in 'duckdb:///:memory:'
# Empty DataFrame
# Columns: [Success]
# Index: []

# %% [markdown]
# ## INDICACAO_RELATADA_NOTIFICADOR_INICIAL

# %%
# %%sql
# SELECT INDICACAO_RELATADA_NOTIFICADOR_INICIAL, count(*) AS qt
# FROM dim_medicamentos
# GROUP BY 1
# ORDER BY qt DESC
# LIMIT 10;
# Out:
# Running query in 'duckdb:///:memory:'
#       INDICACAO_RELATADA_NOTIFICADOR_INICIAL      qt
# 0                                       None  315982
# 1        PRODUCT USED FOR UNKNOWN INDICATION   11420
# 2            DRUG USE FOR UNKNOWN INDICATION    6094
# 3                         ARTRITE REUMATOIDE    3424
# 4                            DOENCA DE CROHN    3213
# 5                                   DIABETES    3030
# 6                                HIPERTENSAO    2904
# 7  PRODUTO USADO PARA INDICACAO DESCONHECIDA    1925
# 8                   ESPONDILITE ANQUILOSANTE    1687
# 9                         MULTIPLE SCLEROSIS    1663

# %% [markdown]
# CONFIRMANDO  QUE NONE É NULL

# %%
# %%sql
# SELECT COUNT(*) AS qt_null
# FROM dim_medicamentos
# WHERE INDICACAO_RELATADA_NOTIFICADOR_INICIAL IS NULL;
# Out:
# Running query in 'duckdb:///:memory:'
#    qt_null
# 0   315982

# %% [markdown]
# ## ficou para mel NUMERO_LOTE

# %%
# %%sql
# SELECT NUMELO_LOTE, count(*) AS qt
# FROM dim_medicamentos
# GROUP BY 1
# ORDER BY qt DESC
# LIMIT 10;
# Out:
# Running query in 'duckdb:///:memory:'
#          NUMELO_LOTE      qt
# 0               None  385104
# 1       DESCONHECIDO   11823
# 2      NAO INFORMADO    5603
# 3                 NI    5187
# 4            UNKNOWN    2907
# 5  ASKED BUT UNKNOWN     705
# 6                UNK     540
# 7       DESCONHECIDA     537
# 8           IGNORADO     515
# 9           4120Z005     303

# %% [markdown]
# CONFIRMANDO NONE = NULL

# %%
# %%sql
# COPY (
#     SELECT
#         NUMELO_LOTE,
#         count(*) AS qt
#     FROM
#         dim_medicamentos
#     GROUP BY
#         1
#     ORDER BY
#         qt DESC
# )
# TO 'relatorio_lotes_duckdb.csv' (HEADER, DELIMITER ';');
# Out:
# Running query in 'duckdb:///:memory:'
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%sql
# SELECT COUNT(*) AS qt_null
# FROM dim_medicamentos
# WHERE NUMELO_LOTE IS NULL;
# Out:
# Running query in 'duckdb:///:memory:'
#    qt_null
# 0   385104

# %% [markdown]
# ## ficou para mel DOSE

# %%
# %%sql
# SELECT DOSE, count(*) AS qt
# FROM dim_medicamentos
# GROUP BY 1
# ORDER BY qt DESC
# limit 10;
# Out:
# Running query in 'duckdb:///:memory:'
#                    DOSE      qt
# 0                  None  339554
# 1    100 MILLIGRAM (MG)   10204
# 2     50 MILLIGRAM (MG)    9612
# 3     10 MILLIGRAM (MG)    8231
# 4    300 MILLIGRAM (MG)    7323
# 5  1 DOSAGE FORM ({DF})    6812
# 6     20 MILLIGRAM (MG)    6795
# 7     40 MILLIGRAM (MG)    6051
# 8    500 MILLIGRAM (MG)    5743
# 9            1 GRAM (G)    5266

# %% [markdown]
# CONFIRMANDO NONE = NULL

# %%
# %%sql
# SELECT COUNT(*) AS qt_null
# FROM dim_medicamentos
# WHERE DOSE IS NULL;
# Out:
# Running query in 'duckdb:///:memory:'
#    qt_null
# 0   339554

# %% [markdown]
# ## ficou para mel FREQUENCIA_DOSE

# %%
# %%sql
# SELECT FREQUENCIA_DOSE, count(*) AS qt
# FROM dim_medicamentos
# GROUP BY 1
# ORDER BY qt DESC
# LIMIT 10;
# Out:
# Running query in 'duckdb:///:memory:'
#   FREQUENCIA_DOSE      qt
# 0    DESCONHECIDO  382662
# 1           1 DIA   34451
# 2     1 POR 1 DIA   16549
# 3               1    8122
# 4         12 HORA    6179
# 5         CICLICO    5583
# 6           TOTAL    5109
# 7   2 POR 12 HORA    4604
# 8           1 MES    3992
# 9        8 SEMANA    3903

# %% [markdown]
# CONFIRMANDO NONE = NULL

# %%
# %%sql
# SELECT COUNT(*) AS qt_null
# FROM dim_medicamentos
# WHERE FREQUENCIA_DOSE IS NULL;
# Out:
# Running query in 'duckdb:///:memory:'
#    qt_null
# 0     3583

# %% [markdown]
# ## ficou para mel DURACAO

# %%
# %%sql
# SELECT DURACAO, count(*) AS qt
# FROM dim_medicamentos
# GROUP BY 1
# ORDER BY qt DESC
# LIMIT 50;
# Out:
# Running query in 'duckdb:///:memory:'
#          DURACAO      qt
# 0   DESCONHECIDO  473049
# 1          1 DIA   20933
# 2          2 DIA    4107
# 3          3 DIA    3079
# 4         1 HORA    2959
# 5          5 DIA    2485
# 6       1 MINUTO    2274
# 7          4 DIA    2253
# 8      30 MINUTO    2101
# 9          7 DIA    1878
# 10        2 HORA    1577
# 11         6 DIA    1501
# 12         0 DIA    1404
# 13         8 DIA    1261
# 14        10 DIA    1105
# 15      5 MINUTO    1070
# 16     10 MINUTO    1058
# 17         9 DIA     843
# 18     20 MINUTO     757
# 19        15 DIA     719
# 20     15 MINUTO     718
# 21        11 DIA     709
# 22        3 HORA     693
# 23        14 DIA     651
# 24        12 DIA     577
# 25     60 MINUTO     576
# 26         1 ANO     576
# 27        22 DIA     563
# 28         1 MES     554
# 29         3 MES     550
# 30         2 MES     544
# 31        13 DIA     512
# 32        4 HORA     472
# 33     90 MINUTO     439
# ...

# %% [markdown]
# CONFIRMANDO  NONE =  NULL

# %%
# %%sql
# SELECT COUNT(*) AS qt_null
# FROM dim_medicamentos
# WHERE DURACAO IS NULL;
# Out:
# Running query in 'duckdb:///:memory:'
#    qt_null
# 0   473049

# %% [markdown]
# ## ok INICIO_ADMINISTRACAO

# %%
# %%sql
# SELECT INICIO_ADMINISTRACAO, count(*) AS qt
# FROM dim_medicamentos
# GROUP BY 1
# ORDER BY qt DESC
# LIMIT 10;
# Out:
# Running query in 'duckdb:///:memory:'
#   INICIO_ADMINISTRACAO      qt
# 0                  NaT  331918
# 1           2020-01-01     546
# 2           2020-01-02     423
# 3           2022-01-01     410
# 4           2021-01-01     410
# 5           2021-07-07     376
# 6           2019-01-01     356
# 7           2021-06-01     349
# 8           2023-01-01     342
# 9           2021-01-21     316

# %% [markdown]
# CONFIRMANDO NAT= NULL

# %%
# %%sql
# SELECT COUNT(*) AS qt_null
# FROM dim_medicamentos
# WHERE INICIO_ADMINISTRACAO IS NULL;
# Out:
# Running query in 'duckdb:///:memory:'
#    qt_null
# 0   331918

# %% [markdown]
# ##  ok FIM_ADMINISTRACAO

# %%
# %%sql
# SELECT FIM_ADMINISTRACAO, count(*) AS qt
# FROM dim_medicamentos
# GROUP BY 1
# ORDER BY qt DESC
# LIMIT 10;
# Out:
# Running query in 'duckdb:///:memory:'
#   FIM_ADMINISTRACAO      qt
# 0               NaT  410120
# 1        2020-01-02     232
# 2        2024-01-02     195
# 3        2020-01-01     191
# 4        2021-07-07     187
# 5        2021-05-19     184
# 6        2021-05-05     172
# 7        2023-02-28     169
# 8        2023-01-02     166
# 9        2021-01-02     166

# %% [markdown]
# CONFIRMANDO  NAT= NULL

# %%
# %%sql
# SELECT COUNT(*) AS qt_null
# FROM dim_medicamentos
# WHERE FIM_ADMINISTRACAO IS NULL;
# Out:
# Running query in 'duckdb:///:memory:'
#    qt_null
# 0   410120

# %% [markdown]
# ## FORMA_FARMACEUTICA

# %%
# %%sql
# SELECT FORMA_FARMACEUTICA, count(*) AS qt
# FROM dim_medicamentos
# GROUP BY 1
# ORDER BY qt DESC
# LIMIT 10;
# Out:
# Running query in 'duckdb:///:memory:'
# RuntimeError: If using snippets, you may pass the --with argument explicitly.
# For more details please refer: https://jupysql.ploomber.io/en/latest/compose.html#with-argument
#
#
# Original error message from DB driver:
# (_duckdb.CatalogException) Catalog Error: Table with name dim_medicamentos does not exist!
# Did you mean "duckdb_constraints"?
#
# LINE 2: FROM dim_medicamentos
#              ^
# [SQL: SELECT FORMA_FARMACEUTICA, count(*) AS qt
# FROM dim_medicamentos
# GROUP BY 1
# ORDER BY qt DESC
# LIMIT 10;]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
#
# COPY(
# SELECT FORMA_FARMACEUTICA, count(*) AS qt
# FROM dim_medicamentos
# GROUP BY 1
# ORDER BY qt DESC
# )
# TO 'forma_farm.csv' (HEADER, DELIMITER ',');
# Out:
# Running query in 'duckdb:///:memory:'
# Empty DataFrame
# Columns: [Success]
# Index: []

# %% [markdown]
# CONFIRMANDO NONE = NULL

# %%
# %%sql
# SELECT COUNT(*) AS qt_null
# FROM dim_medicamentos
# WHERE FORMA_FARMACEUTICA IS NULL;
# Out:
# Running query in 'duckdb:///:memory:'
#    qt_null
# 0   400411

# %% [markdown]
# ## VIA_ADMINISTRACAO

# %%
# %%sql
# SELECT VIA_ADMINISTRACAO, count(*) AS qt
# FROM dim_medicamentos
# GROUP BY 1
# ORDER BY qt DESC
# Out:
# Running query in 'duckdb:///:memory:'
#                                                  VIA_ADMINISTRACAO      qt
# 0                                                     DESCONHECIDO  307548
# 1                                                             ORAL   43987
# 2                                              INFUSAO INTRAVENOSA   26438
# 3                                                    INTRAMUSCULAR   20872
# 4                                                     DESCONHECIDA   18940
# 5                                   INTRAVENOSA (NAO ESPECIFICADO)   18495
# 6                                                               EV   14144
# 7                                                          UNKNOWN   11536
# 8                                                       ENDOVENOSA   10601
# 9                                                       SUBCUTANEA    9775
# 10                                      E2B R2 CODE: 065 - UNKNOWN    9741
# ...

# %% [markdown]
# CONFIRMANDO NONE =  NULL

# %%
# %%sql
#
# COPY (
#     SELECT VIA_ADMINISTRACAO, count(*) AS qt
#     FROM dim_medicamentos
#     GROUP BY 1
#     ORDER BY qt DESC
# ) TO 'via_admin.csv' (HEADER, DELIMITER ',');
# Out:
# Running query in 'duckdb:///:memory:'
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%sql
# SELECT COUNT(*) AS qt_null
# FROM dim_medicamentos
# WHERE VIA_ADMINISTRACAO IS NULL;
# Out:
# Running query in 'duckdb:///:memory:'
#    qt_null
# 0   307203

# %% [markdown]
# ## OK VIA_ADMINISTRACAO_MAE_PAI

# %%
# %%sql
# SELECT VIA_ADMINISTRACAO_MAE_PAI_VALOR, count(*) AS qt
# FROM dim_medicamentos
# GROUP BY 1
# ORDER BY qt DESC
# Out:
# Running query in 'duckdb:///:memory:'
#   VIA_ADMINISTRACAO_MAE_PAI_VALOR      qt
# 0                    DESCONHECIDO  552815
# 1                            ORAL      31
# 2                INTRAVENOSA (IV)      20
# 3                 SUBCUTANEA (SC)      13
# 4              INTRAMUSCULAR (IM)       3
# 5                    RESPIRATORIA       2
# 6                   INTRACEREBRAL       2
# 7                    INTRAUTERINA       1

# %% [markdown]
# CONFIRMANDO NONE = NULL

# %%
# %%sql
# SELECT COUNT(*) AS qt_null
# FROM dim_medicamentos
# WHERE VIA_ADMINISTRACAO_MAE_PAI IS NULL;
# Out:
# Running query in 'duckdb:///:memory:'
#    qt_null
# 0   552748

# %% [markdown]
# ## TESTE  VARIAVEL POSOLOGIA

# %%
# %%sql
# SELECT DOSE, FREQUENCIA_DOSE, FORMA_FARMACEUTICA, VIA_ADMINISTRACAO, DURACAO, POSOLOGIA
# FROM fat_notificacoes_medicamentos
# WHERE DOSE IS NOT NULL
#   AND FREQUENCIA_DOSE IS NOT NULL
#   AND FORMA_FARMACEUTICA IS NOT NULL
#   AND VIA_ADMINISTRACAO IS NOT NULL
#   AND DURACAO IS NOT NULL
#   AND POSOLOGIA IS NOT NULL
# LIMIT 15;
# Out:
# Running query in 'duckdb:///:memory:'
#                    DOSE FREQUENCIA_DOSE   FORMA_FARMACEUTICA  \
# 0     10 milligram (mg)    8 por 8 hora    Solução injetável
# 1     2 millilitre (mL)                  Suspensão injetável
# 2     60 milligram (mg)     2 por 2 dia    Solução injetável
# 3    50 millilitre (mL)     4 por 4 dia    Solução injetável
# 4    150 milligram (mg)   2 por 12 hora    solução injetável
# 5   1500 milligram (mg)    3 por 8 hora           Comprimido
# 6    120 milligram (mg)    6 por 4 hora           Comprimido
# 7    300 milligram (mg)     1 por 1 dia              Cápsula
# 8    100 milligram (mg)                    Solução injetável
# 9    450 milligram (mg)                    Solução injetável
# 10    50 milligram (mg)    4 por 8 hora    Solução injetável
# 11   450 milligram (mg)                    Solução injetável
# 12   100 milligram (mg)                    Solução injetável
# 13   300 milligram (mg)                   Comprimido simples
# ...
