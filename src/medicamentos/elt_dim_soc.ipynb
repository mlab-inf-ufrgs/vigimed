# %% [markdown]
# #  ⭐ `dim_soc`

# %%
# %run ../../config/bootstrap.py


from pathlib import Path
from utils import get_project_root , normalize_atc
 
import pandas as pd

# %%
project_root = get_project_root()

# %% [markdown]
# # 🥉 Bronze
#
# Raw Data
# as is production, low quality

# %% [markdown]
# ### ATC

# %%
bronze_atc = pd.read_excel(Path(project_root) / "data/01_bronze/atc/2025 ATC index with DDDs_english.xlsx")  
renomear = {
    "ATC code": "CODIGO_ATC_LEVEL",
    "ATC level name": "NIVEL_NOME_ATC",
    "DDD": "DDD_VALOR",
    "Unit": "DDD_UNIDADE",
    "Adm.R": "DDD_ADMINISTRACAO",
    "Comment": "DDD_COMENTARIO",
}

bronze_atc = bronze_atc.rename(columns=renomear)

# %%
bronze_atc.head(20)
# Out:
#    CODIGO_ATC_LEVEL                                           NIVEL_NOME_ATC  \
# 0                 A                          ALIMENTARY TRACT AND METABOLISM
# 1               A01                              STOMATOLOGICAL PREPARATIONS
# 2             A01AA                               Caries prophylactic agents
# 3           A01AA01                                          sodium fluoride
# 4           A01AA02                               sodium monofluorophosphate
# 5           A01AA03                                                  olaflur
# 6           A01AA04                                        stannous fluoride
# 7           A01AA30                                             combinations
# 8           A01AA51                            sodium fluoride, combinations
# 9              A01A                              STOMATOLOGICAL PREPARATIONS
# 10            A01AB  Antiinfectives and antiseptics for local oral treatment
# 11          A01AB02                                        hydrogen peroxide
# 12          A01AB03                                            chlorhexidine
# 13          A01AB04                                           amphotericin B
# 14          A01AB05                                              polynoxylin
# 15          A01AB06                                                 domiphen
# 16          A01AB07                                             oxyquinoline
# 17          A01AB08                                                 neomycin
# 18          A01AB09                                               miconazole
# 19          A01AB10                                                natamycin
#
#     DDD_VALOR DDD_UNIDADE DDD_ADMINISTRACAO   DDD_COMENTARIO
# 0         NaN         NaN               NaN              NaN
# 1         NaN         NaN               NaN              NaN
# 2         NaN         NaN               NaN              NaN
# 3        1.10          mg                 O  0.5 mg fluoride
# 4         NaN         NaN               NaN              NaN
# 5        1.10          mg                 O              NaN
# 6         NaN         NaN               NaN              NaN
# 7         NaN         NaN               NaN              NaN
# 8         NaN         NaN               NaN              NaN
# 9         NaN         NaN               NaN              NaN
# 10        NaN         NaN               NaN              NaN
# 11      60.00          mg                 O              NaN
# 12      30.00          mg                 O              NaN
# 13      40.00          mg                 O              NaN
# 14       0.18           g                 O              NaN
# 15       3.00          mg                 O              NaN
# 16      80.00          mg                 O              NaN
# 17        NaN         NaN               NaN              NaN
# 18       0.20           g                 O              NaN
# 19      20.00          mg                 O              NaN

# %%
bronze_atc[bronze_atc["NIVEL_NOME_ATC"].str.contains("oxyquinoline", case=False, na=False)].head(20)
# Out:
#      CODIGO_ATC_LEVEL                NIVEL_NOME_ATC  DDD_VALOR DDD_UNIDADE  \
# 16            A01AB07                  oxyquinoline       80.0          mg
# 465           A07AX01                broxyquinoline        NaN         NaN
# 2483          D08AH03                  oxyquinoline        NaN         NaN
# 2656          G01AC01        diiodohydroxyquinoline        0.2           g
# 2660          G01AC06                broxyquinoline        0.1           g
# 2661          G01AC30                  oxyquinoline        NaN         NaN
# 5898            P01AA  Hydroxyquinoline derivatives        NaN         NaN
# 5899          P01AA01                broxyquinoline        NaN         NaN
# 6175          R02AA14                  oxyquinoline        NaN         NaN
#
#      DDD_ADMINISTRACAO DDD_COMENTARIO
# 16                   O            NaN
# 465                NaN            NaN
# 2483               NaN            NaN
# 2656                 V            NaN
# 2660                 V            NaN
# 2661               NaN            NaN
# 5898               NaN            NaN
# 5899               NaN            NaN
# 6175               NaN            NaN

# %%
bronze_atc.columns
# Out:
# Index(['CODIGO_ATC_LEVEL', 'NIVEL_NOME_ATC', 'DDD_VALOR', 'DDD_UNIDADE',
#        'DDD_ADMINISTRACAO', 'DDD_COMENTARIO'],
#       dtype='object')

# %%
bronze_atc[['CODIGO_ATC_LEVEL', 'NIVEL_NOME_ATC']].describe()
# Out:
#        CODIGO_ATC_LEVEL NIVEL_NOME_ATC
# count              7435           7435
# unique             6897           6045
# top             G03CA03   combinations
# freq                 10             38

# %% [markdown]
# ### MEDICAMENTOS

# %%
 
bronze = pd.read_parquet(Path(project_root) / "data/01_bronze/Medicamentos/Medicamentos.parquet") 
bronze = bronze[['NOME_MEDICAMENTO_WHODRUG', 'PRINCIPIOS_ATIVOS_WHODRUG', 'CODIGO_ATC']].drop_duplicates()
bronze.head(20)
# Out:
#    NOME_MEDICAMENTO_WHODRUG  \
# 0                 Oxacilina
# 1                 Paracemol
# 2                    Diamox
# 3                  Hidantal
# 4            Nitroglicerina
# 5              Macrodantina
# 6           Dexa-Citoneurin
# 7                Benzetacil
# 8                 Reuquinol
# 9            Anfotericina b
# 10             Oxaliplatina
# 11                   Dimorf
# 16                   Gynera
# 17                   Hetori
# 18                  Genuxal
# 19                 Dipirona
# 20                Docelibbs
# 21              Cetoprofeno
# 22               Gentamicin
# 23              Ondansetron
#
#                                                        PRINCIPIOS_ATIVOS_WHODRUG  \
# 0                                                               Oxacillin sodium
# 1                                                                    Paracetamol
# 2                                                           Acetazolamide sodium
# 3                                                                      Phenytoin
# 4                                                            Glyceryl trinitrate
# 5                                                                 Nitrofurantoin
# 6   Cyanocobalamin|Dexamethasone|Pyridoxine hydrochloride|Thiamine hydrochloride
# 7                                                    Benzathine benzylpenicillin
# 8                                                     Hydroxychloroquine sulfate
# 9                                                                 Amphotericin b
# 10                                                                   Oxaliplatin
# 11                                                              Morphine sulfate
# 16                                                    Ethinylestradiol|Gestodene
# 17                                                                    Etoricoxib
# 18                                                              Cyclophosphamide
# 19                                                             Metamizole sodium
# 20                                                                     Docetaxel
# 21                                                                    Ketoprofen
# 22                                                                    Gentamicin
# 23                                                                   Ondansetron
#
#                        CODIGO_ATC
# 0                           J01CF
# 1                           N02BE
# 2                 C03|N03AX|S01EC
# 3                           N03AB
# 4                     C01DA|C05AE
# 5                           J01XE
# 6                           H02BX
# 7                           J01CE
# 8                           P01BA
# 9                           J02AA
# 10                          L01XA
# 11                          N02AA
# 16                          G03AA
# 17                          M01AH
# 18                          L01AA
# 19                          N02BB
# 20                          L01CD
# 21                    M01AE|M02AA
# 22  D06AX|J01GB|S01AA|S02AA|S03AA
# 23                          A04AA

# %%
bronze.describe()
# Out:
#        NOME_MEDICAMENTO_WHODRUG PRINCIPIOS_ATIVOS_WHODRUG CODIGO_ATC
# count                     20224                     20124      20224
# unique                    12490                      6501       2315
# top                     Calcium            Colecalciferol      J01CR
# freq                         19                        60        315

# %%
bronze[bronze["NOME_MEDICAMENTO_WHODRUG"].str.contains("oxyquinoline", case=False, na=False)].head(20)
# Out:
# Empty DataFrame
# Columns: [NOME_MEDICAMENTO_WHODRUG, PRINCIPIOS_ATIVOS_WHODRUG, CODIGO_ATC]
# Index: []

# %%
bronze[bronze["PRINCIPIOS_ATIVOS_WHODRUG"].str.contains("oxyquinoline", case=False, na=False)].head(20)
# Out:
#        NOME_MEDICAMENTO_WHODRUG  \
# 28579                   Cerumin
# 251441              Malvatricin
# 300362              Malvatricin
# 331509                  Cerumin
#
#                                            PRINCIPIOS_ATIVOS_WHODRUG  \
# 28579                              Hydroxyquinoline borate|Trolamine
# 251441                          Hydroxyquinoline sulfate|Tyrothricin
# 300362  Hydroxyquinoline sulfate|Lidocaine hydrochloride|Tyrothricin
# 331509                      Hydroxyquinoline borate_x000D_|Trolamine
#
#          CODIGO_ATC
# 28579         S02DC
# 251441  A01AB|R02AB
# 300362  A01AD|R02AX
# 331509        S02DC

# %% [markdown]
# # 🥈 Silver
#
# normalized data, medium quality

# %%
silver = bronze.copy()

# %%
hist = normalize_atc(silver, bronze_atc, threshold=75)
hist.head()
# Out:
#   NOME_MEDICAMENTO_WHODRUG PRINCIPIOS_ATIVOS_WHODRUG       CODIGO_ATC  \
# 0                Oxacilina          Oxacillin sodium            J01CF
# 1                Paracemol               Paracetamol            N02BE
# 2                   Diamox      Acetazolamide sodium  C03|N03AX|S01EC
# 3                 Hidantal                 Phenytoin            N03AB
# 4           Nitroglicerina       Glyceryl trinitrate      C01DA|C05AE
#
#   CODIGO_ATC_LEVEL  CODIGO_ATC_LEVEL_SCORE
# 0          J01CF04               76.923077
# 1          N02BE01               94.444444
# 2          S01EC01               76.470588
# 3          N03AB02               93.750000
# 4          C01DA02               89.655172

# %%
hist[hist["PRINCIPIOS_ATIVOS_WHODRUG"].str.contains("oxyquinoline", case=False, na=False)].head(20)
# Out:
#        NOME_MEDICAMENTO_WHODRUG  \
# 28579                   Cerumin
# 251441              Malvatricin
# 300362              Malvatricin
# 331509                  Cerumin
#
#                                            PRINCIPIOS_ATIVOS_WHODRUG  \
# 28579                              Hydroxyquinoline borate|Trolamine
# 251441                          Hydroxyquinoline sulfate|Tyrothricin
# 300362  Hydroxyquinoline sulfate|Lidocaine hydrochloride|Tyrothricin
# 331509                      Hydroxyquinoline borate_x000D_|Trolamine
#
#          CODIGO_ATC CODIGO_ATC_LEVEL  CODIGO_ATC_LEVEL_SCORE
# 28579         S02DC     desconhecido                     NaN
# 251441  A01AB|R02AB     desconhecido                     NaN
# 300362  A01AD|R02AX     desconhecido                     NaN
# 331509        S02DC     desconhecido                     NaN

# %%
hist[hist["PRINCIPIOS_ATIVOS_WHODRUG"].str.contains("rituximab", case=False, na=False)].head(40)
# Out:
#                                          NOME_MEDICAMENTO_WHODRUG  \
# 91                                                       Mabthera
# 350                                                     Rituximab
# 10953                                                 Mabthera sc
# 13289                                                    Vivaxxia
# 27060                                                     Riximyo
# 53211                                                      R CHOP
# 65137                                                    Ruxience
# 75255                                                     Rituxan
# 75363                                                     Truxima
# 93432                                                     Truxima
# 160665                                                  Rituximab
# 160758                                                    Riximyo
# 161321                                                   Vivaxxia
# 163456                                                   Mabthera
# 167056                                                    Truxima
# 167263                                               Rituximab bs
# 186706                                                   Ruxience
# 188742                                                Mabthera sc
# 193435                                                    Truxima
# 194835                                                   Mabthera
# 222229                                             Rituximab abbs
# 250616                                                    Rituxan
# 284326                                                Rituximabum
# 302506                                                      R CVP
# 307879                                                    Truxima
# 308348                                                  Rituximab
# 308456                                                    Tuximab
# 309392                                                   Vivaxxia
# 309906                                                    Riximyo
# 317190                                                   Ruxience
# 319831                                                Mabthera sc
# 332525                                                     R CHOP
# 340927                                                   Rixathon
# 374833                                       Rituximab,Venetoclax
# 377999                                        Rituximab bs pfizer
# 379371                                                    Rituxim
# 380311                                                    Truxima
# 385907  Cyclophosphamide,Prednisone,Rituximab,Vincristine sulfate
# 418745                      Cyclophosphamide,Prednisone,Rituximab
# 421035                                               Rituximab bs
#
#                                                                                                   PRINCIPIOS_ATIVOS_WHODRUG  \
# 91                                                                                                                Rituximab
# 350                                                                                                               Rituximab
# 10953                                                                                                             Rituximab
# 13289                                                                                                             Rituximab
# 27060                                                                                                             Rituximab
# 53211                                   Cyclophosphamide|Doxorubicin hydrochloride|Prednisone|Rituximab|Vincristine sulfate
# 65137                                                                                                             Rituximab
# 75255                                                                                                             Rituximab
# 75363                                                                                                             Rituximab
# 93432                                                                                                        Rituximab abbs
# 160665                                                                                                            Rituximab
# 160758                                                                                                            Rituximab
# 161321                                                                                                            Rituximab
# 163456                                                                                                            Rituximab
# 167056                                                                                                            Rituximab
# 167263                                                                                               Rituximab biosimilar 2
# 186706                                                                                                       Rituximab pvvr
# 188742                                                                                                            Rituximab
# 193435                                                                                                       Rituximab abbs
# 194835                                                                                                           Rituximabe
# 222229                                                                                                       Rituximab abbs
# 250616                                                                                                            Rituximab
# 284326                                                                                                            Rituximab
# 302506                                                            Cyclophosphamide|Prednisone|Rituximab|Vincristine sulfate
# 307879                                                                                                           Rituximabe
# 308348                                                                                                           Rituximabe
# 308456                                                                                                           Rituximabe
# 309392                                                                                                           Rituximabe
# 309906                                                                                                           Rituximabe
# 317190                                                                                                           Rituximabe
# 319831                                                                                                           Rituximabe
# 332525  Ciclofosfamida_x000D_|Cloridrato de doxorrubicina_x000D_|Prednisone_x000D_|Rituximabe_x000D_|Sulfato de vincristina
# 340927                                                                                                           Rituximabe
# 374833                                                                                         Rituximabe_x000D_|Venetoclax
# 377999                                                                                               Rituximab biosimilar 2
# 379371                                                                                                           Rituximabe
# 380311                                                                                                           Rituximabe
# 385907                                     Ciclofosfamida_x000D_|Prednisone_x000D_|Rituximabe_x000D_|Sulfato de vincristina
# 418745                                                                   Ciclofosfamida_x000D_|Prednisone_x000D_|Rituximabe
# 421035                                                                                               Rituximab biosimilar 1
#
#                 CODIGO_ATC CODIGO_ATC_LEVEL  CODIGO_ATC_LEVEL_SCORE
# 91                   L01XC          L01FA01               81.250000
# 350                  L01XC          L01FA01               81.250000
# 10953                L01XC          L01FA01               81.250000
# 13289                L01XC          L01FA01               81.250000
# 27060                L01XC          L01FA01               81.250000
# 53211                L01XY     desconhecido                     NaN
# 65137                L01XC          L01FA01               81.250000
# 75255                L01XC          L01FA01               81.250000
# 75363                L01XC          L01FA01               81.250000
# 93432                L01XC          L01FA01               81.250000
# 160665               L01FA          L01FA01               93.750000
# 160758               L01FA          L01FA01               93.750000
# 161321               L01FA          L01FA01               93.750000
# 163456               L01FA          L01FA01               93.750000
# 167056               L01FA          L01FA01               93.750000
# 167263               L01FA          L01FA01               93.750000
# 186706               L01FA          L01FA01               93.750000
# 188742               L01FA          L01FA01               93.750000
# 193435               L01FA          L01FA01               93.750000
# 194835               L01FA          L01FA01               90.909091
# 222229               L01FA          L01FA01               93.750000
# 250616               L01FA          L01FA01               93.750000
# 284326               L01FA          L01FA01               93.750000
# 302506               L01XY     desconhecido                     NaN
# 307879  L01FA_x000D_|L04AG          L01FA01               82.051282
# 308348  L01FA_x000D_|L04AG          L01FA01               82.051282
# 308456               L01FA          L01FA01               90.909091
# 309392               L01FA          L01FA01               90.909091
# 309906               L01FA          L01FA01               90.909091
# 317190               L01FA          L01FA01               90.909091
# 319831               L01FA          L01FA01               90.909091
# 332525               L01XY     desconhecido                     NaN
# 340927               L01FA          L01FA01               90.909091
# 374833               L01XY     desconhecido                     NaN
# 377999               L01FA          L01FA01               93.750000
# 379371               L01FA          L01FA01               90.909091
# 380311               L01FA          L01FA01               90.909091
# 385907               L01XY     desconhecido                     NaN
# 418745               L01XY     desconhecido                     NaN
# 421035               L01FA          L01FA01               93.750000

# %%
hist.query("CODIGO_ATC_LEVEL=='desconhecido'")[hist["PRINCIPIOS_ATIVOS_WHODRUG"].str.contains("rituximab", case=False, na=False)].head(40).sort_values(by="CODIGO_ATC")
# Out:
# /var/folders/6r/t8g0l_4n2h97mg8j0fp43scr0000gn/T/ipykernel_71057/2012540531.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   hist.query("CODIGO_ATC_LEVEL=='desconhecido'")[hist["PRINCIPIOS_ATIVOS_WHODRUG"].str.contains("rituximab", case=False, na=False)].head(40).sort_values(by="CODIGO_ATC")
#                                          NOME_MEDICAMENTO_WHODRUG  \
# 53211                                                      R CHOP
# 302506                                                      R CVP
# 332525                                                     R CHOP
# 374833                                       Rituximab,Venetoclax
# 385907  Cyclophosphamide,Prednisone,Rituximab,Vincristine sulfate
# 418745                      Cyclophosphamide,Prednisone,Rituximab
# 467230                                     Chlorambucil,Rituximab
# 476476                                                    R GEMOX
# 509527                                                        FCR
# 541317                                       Rituximab,Venetoclax
#
#                                                                                                   PRINCIPIOS_ATIVOS_WHODRUG  \
# 53211                                   Cyclophosphamide|Doxorubicin hydrochloride|Prednisone|Rituximab|Vincristine sulfate
# 302506                                                            Cyclophosphamide|Prednisone|Rituximab|Vincristine sulfate
# 332525  Ciclofosfamida_x000D_|Cloridrato de doxorrubicina_x000D_|Prednisone_x000D_|Rituximabe_x000D_|Sulfato de vincristina
# 374833                                                                                         Rituximabe_x000D_|Venetoclax
# 385907                                     Ciclofosfamida_x000D_|Prednisone_x000D_|Rituximabe_x000D_|Sulfato de vincristina
# 418745                                                                   Ciclofosfamida_x000D_|Prednisone_x000D_|Rituximabe
# 467230                                                                                       Clorambucila_x000D_|Rituximabe
# 476476                                                                    Gencitabina_x000D_|Oxaliplatina_x000D_|Rituximabe
# 509527                                                                  Ciclofosfamida_x000D_|Fludarabine_x000D_|Rituximabe
# 541317                                                                                                Rituximabe|Venetoclax
#
#        CODIGO_ATC CODIGO_ATC_LEVEL  CODIGO_ATC_LEVEL_SCORE
# 53211       L01XY     desconhecido                     NaN
# 302506      L01XY     desconhecido                     NaN
# 332525      L01XY     desconhecido                     NaN
# 374833      L01XY     desconhecido                     NaN
# 385907      L01XY     desconhecido                     NaN
# 418745      L01XY     desconhecido                     NaN
# 467230      L01XY     desconhecido                     NaN
# 476476      L01XY     desconhecido                     NaN
# 509527      L01XY     desconhecido                     NaN
# 541317      L01XY     desconhecido                     NaN

# %%
hist.query("CODIGO_ATC_LEVEL=='desconhecido'")[hist["PRINCIPIOS_ATIVOS_WHODRUG"].str.contains("ertolizumab", case=False, na=False)].head(40).sort_values(by="CODIGO_ATC")
# Out:
# /var/folders/6r/t8g0l_4n2h97mg8j0fp43scr0000gn/T/ipykernel_71057/2000822013.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   hist.query("CODIGO_ATC_LEVEL=='desconhecido'")[hist["PRINCIPIOS_ATIVOS_WHODRUG"].str.contains("ertolizumab", case=False, na=False)].head(40).sort_values(by="CODIGO_ATC")
# Empty DataFrame
# Columns: [NOME_MEDICAMENTO_WHODRUG, PRINCIPIOS_ATIVOS_WHODRUG, CODIGO_ATC, CODIGO_ATC_LEVEL, CODIGO_ATC_LEVEL_SCORE]
# Index: []

# %%
histv2 = hist.query("CODIGO_ATC_LEVEL=='desconhecido'")[hist["PRINCIPIOS_ATIVOS_WHODRUG"].str.contains("ertolizumab", case=False, na=False)].head(40).sort_values(by="CODIGO_ATC")
histv2 = normalize_atc(histv2, bronze_atc, threshold=75)
histv2.head()
# Out:
# /var/folders/6r/t8g0l_4n2h97mg8j0fp43scr0000gn/T/ipykernel_71057/3878801764.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   histv2 = hist.query("CODIGO_ATC_LEVEL=='desconhecido'")[hist["PRINCIPIOS_ATIVOS_WHODRUG"].str.contains("ertolizumab", case=False, na=False)].head(40).sort_values(by="CODIGO_ATC")
# Empty DataFrame
# Columns: [NOME_MEDICAMENTO_WHODRUG, PRINCIPIOS_ATIVOS_WHODRUG, CODIGO_ATC, CODIGO_ATC_LEVEL, CODIGO_ATC_LEVEL_SCORE]
# Index: []

# %%
hist[hist["PRINCIPIOS_ATIVOS_WHODRUG"].str.contains("golimumab", case=False, na=False)].head(20)
# Out:
#          NOME_MEDICAMENTO_WHODRUG PRINCIPIOS_ATIVOS_WHODRUG CODIGO_ATC  \
# 1651                      Simponi                 Golimumab      L04AB
# 10798                   Golimumab                 Golimumab      L04AB
# 267667               Simponi aria                 Golimumab      L04AB
# 307771                    Simponi                Golimumabe      L04AB
# 308109                  Golimumab                Golimumabe      L04AB
# 320610  Bio manguinhos golimumabe                Golimumabe      L04AB
# 412527      Golimumab recombinant                Golimumabe      L04AB
# 445904                 Simponi iv                Golimumabe      L04AB
#
#        CODIGO_ATC_LEVEL  CODIGO_ATC_LEVEL_SCORE
# 1651            L04AB06               93.750000
# 10798           L04AB06               93.750000
# 267667          L04AB06               93.750000
# 307771          L04AB06               90.909091
# 308109          L04AB06               90.909091
# 320610          L04AB06               90.909091
# 412527          L04AB06               90.909091
# 445904          L04AB06               90.909091

# %%
hist[hist["PRINCIPIOS_ATIVOS_WHODRUG"].str.contains("infliximab", case=False, na=False)].head(20)
# Out:
#           NOME_MEDICAMENTO_WHODRUG PRINCIPIOS_ATIVOS_WHODRUG CODIGO_ATC  \
# 152                       Remicade                Infliximab      L04AB
# 164     Bio manguinhos infliximabe                Infliximab      L04AB
# 859                     Infliximab                Infliximab      L04AB
# 5437                       Remsima                Infliximab      L04AB
# 34679         Infliximab bs pfizer   Infliximab biosimilar 3      L04AB
# 53570         Remicade lyophilisat                Infliximab      L04AB
# 88179       Infliximab Recombinant                Infliximab      L04AB
# 96237              Infliximab dyyb           Infliximab dyyb      L04AB
# 103939      Infliximab bs nichiiko                Infliximab      L04AB
# 151373                      Xilfya                Infliximab      L04AB
# 215557     Infliximab biosimilar 1   Infliximab biosimilar 1      L04AB
# 302016                      Avsola                Infliximab      L04AB
# 307778                  Infliximab               Infliximabe      L04AB
# 307779                    Remicade               Infliximabe      L04AB
# 308183                     Remsima               Infliximabe      L04AB
# 308549  Bio manguinhos infliximabe               Infliximabe      L04AB
# 309184                      Xilfya               Infliximabe      L04AB
# 309545      Infliximab Recombinant               Infliximabe      L04AB
# 315167                      Avsola               Infliximabe      L04AB
# 403322                Infliximabum               Infliximabe      L04AB
#
#        CODIGO_ATC_LEVEL  CODIGO_ATC_LEVEL_SCORE
# 152             L04AB02               94.117647
# 164             L04AB02               94.117647
# 859             L04AB02               94.117647
# 5437            L04AB02               94.117647
# 34679           L04AB02               94.117647
# 53570           L04AB02               94.117647
# 88179           L04AB02               94.117647
# 96237           L04AB02               82.051282
# 103939          L04AB02               94.117647
# 151373          L04AB02               94.117647
# 215557          L04AB02               94.117647
# 302016          L04AB02               94.117647
# 307778          L04AB02               91.428571
# 307779          L04AB02               91.428571
# 308183          L04AB02               91.428571
# 308549          L04AB02               91.428571
# 309184          L04AB02               91.428571
# 309545          L04AB02               91.428571
# 315167          L04AB02               91.428571
# 403322          L04AB02               91.428571

# %%
hist.to_csv(
    Path(project_root) / "data/02_silver/hist_dim_atc/hist_dim_atc_MANUAL.csv",
    sep=";",
    decimal=",",
    encoding="utf-8-sig",   # em vez de utf-8
    index=False,
)

# %%
silver.head(2)
# Out:
#   NOME_MEDICAMENTO_WHODRUG PRINCIPIOS_ATIVOS_WHODRUG CODIGO_ATC  \
# 0                Oxacilina          Oxacillin sodium      J01CF
# 1                Paracemol               Paracetamol      N02BE
#
#   CODIGO_ATC_LEVEL  CODIGO_ATC_LEVEL_SCORE
# 0          J01CF04               76.923077
# 1          N02BE01               94.444444

# %% [markdown]
# # 🥇 Gold

# %%
hist.columns
# Out:
# Index(['NOME_MEDICAMENTO_WHODRUG', 'PRINCIPIOS_ATIVOS_WHODRUG', 'CODIGO_ATC',
#        'CODIGO_ATC_LEVEL', 'CODIGO_ATC_LEVEL_SCORE'],
#       dtype='object')

# %%
#dim = hist[['DETENTOR_REGISTRO_CHAVE', 'DETENTOR_REGISTRO_VALOR']].drop_duplicates()
#dim.to_parquet(Path(project_root) / "data/03_gold/dim_detentor_registro/dim_detentor_registro.parquet", index=False)

# %%
#dim.to_csv(Path(project_root) / "data/03_gold/dim_detentor_registro/dim_detentor_registro.csv", sep=";", index=False)
